# %%
from typing import Union, Tuple
import numpy as np
import pandas as pd
import datetime

# %%
df = pd.read_parquet('data/msci_world_index.parquet')

# %%
class SavingPlan:
    """ 
    This class is used to calculate the total worth of a saving plan 
    that invests a fixed amount of money on a fixed day of the month.

    Parameters
    ----------
    df : pd.DataFrame
        A pandas DataFrame containing the stock data.
    invest_amount : int
        The amount of money to invest on the fixed day of the month.
    day_to_invest : int
        The day of the month to invest the money.
    period : str or Tuple[datetime.datetime, datetime.datetime]
        The period to consider. If a string is passed, the only available value is "max".
        If a tuple is passed, it should contain two datetime.datetime objects.
    
    Attributes
    ----------
    total_worth : float
        The total worth of the saving plan.    
    """
    def __init__(self, 
                 df: pd.DataFrame,
                 invest_amount: int,
                 day_to_invest: int,
                 period: Union[str, Tuple[datetime.datetime, datetime.datetime]]):
        self.df = df
        self.invest_amount = invest_amount
        self.day_to_invest = day_to_invest
        self.period = period

        if isinstance(self.period, str):
            assert self.period == "max", "If using string the only available value is 'max'"
    
        self.df = df

        if self.df.index.tz:
            self.df.index = self.df.index.tz_convert(None)

        if isinstance(self.period, tuple):
            self.df = self.df.loc[self.period[0]: self.period[1]]
            
    
        self.close_column = "Close"

        self.prepared_df = self.prepare_data()

        self._total_worth = None

    @property
    def total_worth(self):
        if self._total_worth is None:
            self._total_worth = self.prepared_df.tail(1)["total_worth"].iloc[0].item()
        return self._total_worth

    def select_required_columns(self, df: pd.DataFrame) -> pd.DataFrame:
        columns_to_drop = [x for x in df.columns if x != self.close_column]
        return df.drop(columns_to_drop, axis=1)
    
    def rename_close(self, df) -> pd.DataFrame:
        return df.rename({self.close_column: "price"}, axis=1)

    def sort_date(self, df: pd.DataFrame) -> pd.DataFrame:
        return df.sort_index()

    def add_day_of_month(self, df: pd.DataFrame) -> pd.DataFrame:
        """Add the day of the month to the DataFrame."""
        df["day_of_month"]=  df.index.day
        return df
    
    def _find_next_trading_day(self, x: pd.Series, day: int) -> int:
        """Find the next trading day in the Series x after the day of the month day."""
        # Perform a binary search to find the index where the target day should be inserted
        idx = np.searchsorted(x, day, side='left')
        
        # If the index is within bounds, return the next day, otherwise wrap around
        if idx < len(x):
            return x.iloc[idx]
        else:
            return x.iloc[-1] 

    def add_real_day_to_invest(self, df: pd.DataFrame) -> pd.DataFrame:
        """Add the real day to invest to the DataFrame."""
        df["day_to_invest"] = df.groupby(pd.Grouper(freq="1ME"))["day_of_month"].transform(self._find_next_trading_day, day=self.day_to_invest)

        return df
    
    def add_saving(self, df:pd.DataFrame) -> pd.DataFrame:
        """Add the saving executed on the day to invest."""
        df.loc[df.day_of_month == df.day_to_invest, "invest_amount"] = self.invest_amount
        return df

    def add_number_of_stocks_bought(self, df: pd.DataFrame) -> pd.DataFrame:
        df["number_of_stocks_bought"] = df["invest_amount"] / df["price"]
        return df
    
    def add_number_of_stocks(self, df: pd.DataFrame) -> pd.DataFrame:
        df["number_of_stocks"] = df["number_of_stocks_bought"].cumsum()
        return df
    
    def add_total_worth(self, df: pd.DataFrame) -> pd.DataFrame:
        df["total_worth"] = df["number_of_stocks"] * df["price"]
        return df
    
    def prepare_data(self):
        result = (
            self.df
            .pipe(self.select_required_columns)
            .pipe(self.rename_close)
            .pipe(self.add_day_of_month)
            .pipe(self.sort_date)
            .pipe(self.add_real_day_to_invest)
            .pipe(self.add_saving)
            .pipe(self.add_number_of_stocks_bought)
            .pipe(self.add_number_of_stocks)
            .pipe(self.add_total_worth)
            .dropna()
            )
        
        return result

# %% [markdown]
# # Initial performane

# %%
# %%timeit

saving_plan = SavingPlan(df, 100, 1, "max")
saving_plan.total_worth
# Out:
# 46.3 ms ± 298 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# # Using numpy

# %%
class SavingPlan:
    def __init__(self, 
                 df: pd.DataFrame,
                 invest_amount: int,
                 day_to_invest: int,
                 period: Union[str, Tuple[datetime.datetime, datetime.datetime]]):
        self.df = df
        self.invest_amount = invest_amount
        self.day_to_invest = day_to_invest
        self.period = period

        if isinstance(self.period, str):
            assert self.period == "max", "If using string the only available value is 'max'"
    
        self.df = df

        if self.df.index.tz:
            self.df.index = self.df.index.tz_convert(None)

        if isinstance(self.period, tuple):
            self.df = self.df.loc[self.period[0]: self.period[1]]
            
    
        self.close_column = "Close"

        self.prepared_df = self.prepare_data()

        self._total_worth = None

    @property
    def total_worth(self):
        if self._total_worth is None:
            self._total_worth = self.prepared_df.tail(1)["total_worth"].iloc[0].item()
        return self._total_worth

    def select_required_columns(self, df: pd.DataFrame) -> pd.DataFrame:
        columns_to_drop = [x for x in df.columns if x != self.close_column]
        return df.drop(columns_to_drop, axis=1)
    
    def rename_close(self, df) -> pd.DataFrame:
        return df.rename({self.close_column: "price"}, axis=1)

    def sort_date(self, df: pd.DataFrame) -> pd.DataFrame:
        return df.sort_index()

    def add_day_of_month(self, df: pd.DataFrame) -> pd.DataFrame:
        """Add the day of the month to the DataFrame."""
        df["day_of_month"]=  df.index.day
        return df
    
    @jit
    def _find_next_trading_day(self, x: pd.Series, day: int) -> int:
        """Find the next trading day in the Series x after the day of the month day."""
        # Perform a binary search to find the index where the target day should be inserted
        idx = np.searchsorted(x, day, side='left')
        
        # If the index is within bounds, return the next day, otherwise wrap around
        if idx < len(x):
            return x.iloc[idx]
        else:
            return x.iloc[-1] 

    def add_real_day_to_invest(self, df: pd.DataFrame) -> pd.DataFrame:
        """Add the real day to invest to the DataFrame."""
        df["day_to_invest"] = df.groupby(pd.Grouper(freq="1ME"))["day_of_month"].transform(self._find_next_trading_day, day=self.day_to_invest)

        return df
    
    def add_saving(self, df:pd.DataFrame) -> pd.DataFrame:
        """Add the saving executed on the day to invest."""
        df.loc[df.day_of_month == df.day_to_invest, "invest_amount"] = self.invest_amount
        return df

    def add_number_of_stocks_bought(self, df: pd.DataFrame) -> pd.DataFrame:
        df["number_of_stocks_bought"] = df["invest_amount"] / df["price"]
        return df
    
    def add_number_of_stocks(self, df: pd.DataFrame) -> pd.DataFrame:
        df["number_of_stocks"] = df["number_of_stocks_bought"].cumsum()
        return df
    
    def add_total_worth(self, df: pd.DataFrame) -> pd.DataFrame:
        df["total_worth"] = df["number_of_stocks"] * df["price"]
        return df
    
    def prepare_data(self):
        result = (
            self.df
            .pipe(self.select_required_columns)
            .pipe(self.rename_close)
            .pipe(self.add_day_of_month)
            .pipe(self.sort_date)
            .pipe(self.add_real_day_to_invest)
            .pipe(self.add_saving)
            .pipe(self.add_number_of_stocks_bought)
            .pipe(self.add_number_of_stocks)
            .pipe(self.add_total_worth)
            .dropna()
            )
        
        return result

# %%
# %%timeit

saving_plan = SavingPlan(df, 100, 1, "max")
saving_plan.total_worth
# Out:
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 get_ipython().run_cell_magic('timeit', '', '\nsaving_plan = SavingPlan(df, 100, 1, "max")\nsaving_plan.total_worth\n')
#
# File ~/Projects/best-day-to-save/.venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/Projects/best-day-to-save/.venv/lib/python3.10/site-packages/IPython/core/magics/execution.py:1185, in ExecutionMagics.timeit(self, line, cell, local_ns)
#    1183 for index in range(0, 10):
#    1184     number = 10 ** index
# -> 1185     time_number = timer.timeit(number)
#    1186     if time_number >= 0.2:
#    1187         break
#
# File ~/Projects/best-day-to-save/.venv/lib/python3.10/site-packages/IPython/core/magics/execution.py:173, in Timer.timeit(self, number)
#     171 gc.disable()
#     172 try:
# --> 173     timing = self.inner(it, self.timer)
#     174 finally:
#     175     if gcold:
#
# File <magic-timeit>:1, in inner(_it, _timer)
#
# Cell In[10], line 47, in SavingPlan.__init__(self, df, invest_amount, day_to_invest, period)
#      42     self.df = self.df.loc[self.period[0]: self.period[1]]
#      45 self.close_column = "Close"
# ---> 47 self.prepared_df = self.prepare_data()
#      49 self._total_worth = None
#
# Cell In[10], line 114, in SavingPlan.prepare_data(self)
#     107 def prepare_data(self):
#     108     result = (
#     109         self.df
#     110         .pipe(self.select_required_columns)
#     111         .pipe(self.rename_close)
#     112         .pipe(self.add_day_of_month)
#     113         .pipe(self.sort_date)
# --> 114         .pipe(self.add_real_day_to_invest)
#     115         .pipe(self.add_saving)
#     116         .pipe(self.add_number_of_stocks_bought)
#     117         .pipe(self.add_number_of_stocks)
#     118         .pipe(self.add_total_worth)
#     119         .dropna()
#     120         )
#     122     return result
#
# File ~/Projects/best-day-to-save/.venv/lib/python3.10/site-packages/pandas/core/generic.py:6231, in NDFrame.pipe(self, func, *args, **kwargs)
#    6229 if using_copy_on_write():
#    6230     return common.pipe(self.copy(deep=None), func, *args, **kwargs)
# -> 6231 return common.pipe(self, func, *args, **kwargs)
#
# File ~/Projects/best-day-to-save/.venv/lib/python3.10/site-packages/pandas/core/common.py:502, in pipe(obj, func, *args, **kwargs)
#     500     return func(*args, **kwargs)
#     501 else:
# --> 502     return func(obj, *args, **kwargs)
#
# Cell In[10], line 86, in SavingPlan.add_real_day_to_invest(self, df)
#      84 def add_real_day_to_invest(self, df: pd.DataFrame) -> pd.DataFrame:
#      85     """Add the real day to invest to the DataFrame."""
# ---> 86     df["day_to_invest"] = df.groupby(pd.Grouper(freq="1ME"))["day_of_month"].transform(self._find_next_trading_day, day=self.day_to_invest)
#      88     return df
#
# File ~/Projects/best-day-to-save/.venv/lib/python3.10/site-packages/pandas/core/groupby/generic.py:517, in SeriesGroupBy.transform(self, func, engine, engine_kwargs, *args, **kwargs)
#     514 @Substitution(klass="Series", example=__examples_series_doc)
#     515 @Appender(_transform_template)
#     516 def transform(self, func, *args, engine=None, engine_kwargs=None, **kwargs):
# --> 517     return self._transform(
#     518         func, *args, engine=engine, engine_kwargs=engine_kwargs, **kwargs
#     519     )
#
# File ~/Projects/best-day-to-save/.venv/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:2021, in GroupBy._transform(self, func, engine, engine_kwargs, *args, **kwargs)
#    2018     warn_alias_replacement(self, orig_func, func)
#    2020 if not isinstance(func, str):
# -> 2021     return self._transform_general(func, engine, engine_kwargs, *args, **kwargs)
#    2023 elif func not in base.transform_kernel_allowlist:
#    2024     msg = f"'{func}' is not a valid function name for transform(name)"
#
# File ~/Projects/best-day-to-save/.venv/lib/python3.10/site-packages/pandas/core/groupby/generic.py:557, in SeriesGroupBy._transform_general(self, func, engine, engine_kwargs, *args, **kwargs)
#     552 for name, group in self._grouper.get_iterator(
#     553     self._obj_with_exclusions, axis=self.axis
#     554 ):
#     555     # this setattr is needed for test_transform_lambda_with_datetimetz
#     556     object.__setattr__(group, "name", name)
# --> 557     res = func(group, *args, **kwargs)
#     559     results.append(klass(res, index=group.index))
#     561 # check for empty "results" to avoid concat ValueError
#
# File ~/Projects/best-day-to-save/.venv/lib/python3.10/site-packages/numba/core/dispatcher.py:423, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     419         msg = (f"{str(e).rstrip()} \n\nThis error may have been caused "
#     420                f"by the following argument(s):\n{args_str}\n")
#     421         e.patch_message(msg)
# --> 423     error_rewrite(e, 'typing')
#     424 except errors.UnsupportedError as e:
#     425     # Something unsupported is present in the user code, add help info
#     426     error_rewrite(e, 'unsupported_error')
#
# File ~/Projects/best-day-to-save/.venv/lib/python3.10/site-packages/numba/core/dispatcher.py:364, in _DispatcherBase._compile_for_args.<locals>.error_rewrite(e, issue_type)
#     362     raise e
#     363 else:
# --> 364     raise e.with_traceback(None)
#
# TypingError: Failed in nopython mode pipeline (step: nopython frontend)
# non-precise type pyobject
# During: typing of argument at /var/folders/n0/_ynk_mts4cg0tzzzy408rqyh0000gn/T/ipykernel_40741/3657267690.py (72)
#
# File "../../../../var/folders/n0/_ynk_mts4cg0tzzzy408rqyh0000gn/T/ipykernel_40741/3657267690.py", line 72:
# <source missing, REPL/exec in use?>
#
# This error may have been caused by the following argument(s):
# - argument 0: Cannot determine Numba type of <class '__main__.SavingPlan'>
# - argument 1: Cannot determine Numba type of <class 'pandas.core.series.Series'>

# %%
prices = df["Close"].to_numpy()
dates = df.index.date

# Extract the months
months = np.array([date.month for date in dates])
years = np.array([date.year for date in dates])
day_of_month = np.array([date.day for date in dates])

#  Find the indices where the month and year change
change_indices = np.where((months[:-1] != months[1:]) | (years[:-1] != years[1:]))[0] + 1

# Split the dates array at the change indices

split_dates = np.split(dates, change_indices)

def find_next_trading_day(x: np.ndarray, days: np.ndarray) -> int:
    # Perform a binary search to find the index where the target day should be inserted
    idx = np.searchsorted(x, days, side='left')
    return idx
    

def encode_date(date: datetime.date) -> int:
    
    return date.year * 10000 + date.month * 100 + date.day

def decode_date(x: int) -> datetime.date:
    year = x // 10000
    month = (x - year * 10000) // 100
    day = x - year * 10000 - month * 100
    return datetime.date(year, month, day)

def encode_dates_to_ints(x: np.ndarray) -> np.ndarray:
    """I want to convert the dates to intigers, which can help find
    the next invest day
    """
    
    return np.array([encode_date(date) for date in x])

def decode_dates_from_ints(x: np.ndarray) -> np.ndarray:

    return np.array([decode_date(date) for date in x])

# get all years and months from min dates to max dates  
def generate_day_ints(dates: np.ndarray, day: np.ndarray) -> np.ndarray:
    """Generate the day ints from the dates."""
    years = np.unique([date.year for date in dates])
    months = np.unique([date.month for date in dates])

    for year in years:
        for month in months:
            if (year >= 2024) and (month >= 10) and (day < 4):
                break
            yield year * 10000 + month * 100 + day

indices = find_next_trading_day(encode_dates_to_ints(dates),list(generate_day_ints(dates, day)) )

invest_amount = 10
bought_stocks = invest_amount / prices[indices]

all_stocks = np.cumsum(bought_stocks)

total_worth = all_stocks * prices[indices]

# %%
len(prices[indices])
# Out:
# 633

# %%
total_worth[-1]
# Out:
# np.float64(65363.184988472385)

# %% [markdown]
# # Summerize results

# %%
class SavingPlan:
    def __init__(self, 
                 df: pd.DataFrame,
                 invest_amount: int,
                 day_to_invest: int,
                 period: Union[str, Tuple[datetime.datetime, datetime.datetime]]):
        self.df = df
        self.invest_amount = invest_amount
        self.day_to_invest = day_to_invest
        self.period = period

        if isinstance(self.period, str):
            assert self.period == "max", "If using string the only available value is 'max'"

        self.df = df

        if isinstance(self.period, tuple):
            self.df = self.df.loc[self.period[0]: self.period[1]]

        self.prices = self.df["Close"].to_numpy()
        self.dates = self.df.index.date

        self._indices = None
        self._bought_stocks = None
        self._all_stocks = None
        self._total_worth = None

    @property
    def indices(self):
        if self._indices is None:
            self._indices = self.get_indices()
        
        return self._indices
    
    @property
    def invest_days(self):
        return self.dates[self.indices]
    
    @property
    def bought_stocks(self):
        if self._bought_stocks is None:
            self._bought_stocks = self.invest_amount / self.prices[self.indices]
        
        return self._bought_stocks
    
    @property
    def all_stocks(self):
        if self._all_stocks is None:
            self._all_stocks = np.cumsum(self.bought_stocks)
        
        return self._all_stocks
    
    @property
    def total_worth(self):
        if self._total_worth is None:
            self._total_worth = self.all_stocks * self.prices[self.indices][-1]
        
        return self._total_worth[-1]
    
    def find_next_trading_day(self, x: np.ndarray, days: np.ndarray) -> int:
        # Perform a binary search to find the index where the target day should be inserted
        idx = np.searchsorted(x, days, side='left')
        return idx
    
    def encode_date(self, date: datetime.date) -> int:
        return date.year * 10000 + date.month * 100 + date.day
    
    def decode_date(self, x: int) -> datetime.date:
        year = x // 10000
        month = (x - year * 10000) // 100
        day = x - year * 10000 - month * 100
        return datetime.date(year, month, day)
    
    def encode_dates_to_ints(self, x: np.ndarray) -> np.ndarray:
        """I want to convert the dates to intigers, which can help find
        the next invest day
        """
        return np.array([self.encode_date(date) for date in x])
    
    def decode_dates_from_ints(self, x: np.ndarray) -> np.ndarray:
        return np.array([self.decode_date(date) for date in x])
    
    def generate_day_ints(self, dates: np.ndarray, day: np.ndarray) -> np.ndarray:
        """Generate the day ints from the dates."""
        years = np.unique([date.year for date in dates])
        months = np.unique([date.month for date in dates])

        for year in years:
            for month in months:
                if (year >= 2024) and (month >= 10) and (day < 4):
                    break
                yield year * 10000 + month * 100 + day

    def get_indices(self):
        encoded_dates = self.encode_dates_to_ints(self.dates)
        selected_day_ints = list(self.generate_day_ints(self.dates, self.day_to_invest))
        indices = self.find_next_trading_day(encoded_dates, selected_day_ints)
        return indices

# %%
# %%timeit
saving_plan = SavingPlan(df, 10, 1, "max")
saving_plan.total_worth
# Out:
# 8.68 ms ± 74.9 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
list(generate_day_ints(dates, day))[-3:]
# Out:
# [np.int64(20240701), np.int64(20240801), np.int64(20240901)]

# %%
encoded_dates = encode_dates_to_ints(dates)

# check whether the next value is always greater than the previous one
np.all(np.diff(encoded_dates) > 0)
# Out:
# np.True_

# %%
encoded_dates
# Out:
# array([19720103, 19720104, 19720105, ..., 20240829, 20240830, 20240903])

# %%
2000 * (10000) + 11 * (100) + 31
# Out:
# 20001131

# %%
2001 * (10000) + (1) * 12 * (100) + 1
# Out:
# 20011201

# %%
result = []
for all_days, target_day in zip(split_dates, days_to_invest):
    for day in all_days:
        if day.day == target_day:
            result.append(day)

# %%
split_dates
# Out:
# [array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([1]),
#  array([], dtype=int64),
#  array([1]),
#  array([1]),
#  array([], dtype=int64)]

# %%
days_to_invest
# Out:
# array([3, 1, 1, 3, 1, 1, 3, 1, 1, 2, 1, 1, 2, 1, 1, 2, 1, 1, 2, 1, 3, 1,
#        1, 3, 2, 1, 1, 1, 1, 3, 1, 1, 2, 1, 1, 2, 2, 3, 3, 1, 1, 2, 1, 1,
#        1, 1, 3, 1, 2, 2, 1, 1, 3, 1, 1, 2, 1, 1, 1, 1, 3, 1, 1, 1, 2, 1,
#        1, 1, 1, 3, 1, 1, 2, 1, 1, 3, 1, 1, 3, 1, 1, 2, 1, 1, 2, 1, 1, 2,
#        1, 1, 2, 1, 3, 1, 1, 3, 2, 1, 3, 1, 1, 2, 1, 1, 1, 1, 3, 1, 2, 2,
#        2, 1, 1, 1, 1, 3, 1, 1, 2, 1, 4, 1, 1, 1, 3, 1, 1, 2, 1, 1, 1, 1,
#        3, 1, 1, 1, 2, 1, 1, 1, 1, 3, 1, 1, 2, 1, 1, 2, 1, 1, 2, 1, 3, 1,
#        1, 3, 2, 1, 1, 1, 1, 3, 1, 1, 2, 1, 1, 2, 2, 3, 3, 1, 1, 2, 1, 1,
#        1, 1, 3, 1, 2, 2, 2, 1, 1, 1, 1, 3, 1, 1, 2, 1, 4, 1, 1, 1, 2, 1,
#        1, 1, 1, 3, 1, 1, 2, 1, 1, 3, 1, 1, 3, 1, 1, 2, 1, 1, 2, 1, 1, 2,
#        1, 1, 2, 1, 3, 1, 1, 3, 2, 1, 1, 1, 1, 3, 1, 1, 2, 1, 1, 2, 2, 3,
#        2, 1, 1, 1, 1, 3, 1, 1, 2, 1, 4, 1, 1, 1, 3, 1, 1, 2, 1, 1, 1, 1,
#        3, 1, 1, 1, 2, 1, 1, 1, 1, 3, 1, 1, 3, 1, 1, 3, 1, 1, 3, 1, 1, 2,
#        1, 1, 2, 1, 1, 1, 1, 3, 1, 1, 3, 1, 1, 2, 2, 3, 3, 1, 1, 2, 1, 1,
#        2, 1, 3, 1, 2, 2, 2, 1, 1, 1, 1, 3, 1, 1, 2, 1, 4, 1, 1, 1, 3, 1,
#        1, 2, 1, 1, 1, 1, 3, 1, 1, 3, 1, 1, 3, 1, 1, 2, 1, 1, 2, 1, 1, 2,
#        1, 1, 2, 1, 3, 1, 1, 3, 2, 1, 1, 1, 1, 3, 1, 1, 2, 1, 1, 2, 2, 3,
#        3, 1, 1, 2, 1, 1, 1, 1, 3, 1, 2, 2, 1, 1, 3, 1, 1, 2, 1, 1, 1, 1,
#        3, 1, 1, 1, 2, 1, 1, 1, 1, 3, 1, 1, 2, 1, 1, 3, 1, 1, 3, 1, 1, 2,
#        1, 1, 2, 1, 1, 2, 1, 1, 2, 1, 4, 1, 1, 3, 2, 1, 3, 1, 1, 2, 1, 1,
#        2, 1, 3, 1, 2, 2, 2, 1, 1, 1, 1, 3, 1, 1, 2, 1, 4, 1, 1, 1, 3, 1,
#        1, 2, 1, 1, 1, 1, 3, 1, 1, 1, 2, 1, 1, 1, 1, 3, 1, 1, 3, 1, 1, 2,
#        1, 1, 2, 1, 4, 1, 1, 3, 2, 1, 1, 1, 1, 3, 1, 1, 3, 1, 1, 2, 2, 3,
#        3, 1, 1, 2, 1, 1, 2, 1, 3, 1, 2, 2, 2, 1, 1, 1, 1, 3, 1, 1, 2, 1,
#        4, 1, 1, 1, 2, 1, 1, 1, 1, 3, 1, 1, 3, 1, 1, 3, 1, 1, 3, 1, 1, 2,
#        1, 1, 2, 1, 1, 2, 1, 1, 2, 1, 4, 1, 1, 3, 2, 1, 1, 1, 1, 3, 1, 1,
#        3, 1, 1, 2, 2, 3, 2, 1, 1, 1, 1, 3, 1, 1, 2, 1, 4, 1, 1, 1, 3, 1,
#        1, 2, 1, 1, 1, 1, 3, 1, 1, 1, 2, 1, 1, 1, 1, 3, 1, 1, 3, 1, 1, 3,
#        1, 1, 3, 1, 1, 2, 1, 1, 2, 1, 1, 1, 1, 3, 1, 1, 3])

# %%
find_next_trading_day(split_dates[0], 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Projects/best-day-to-save/.venv/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#
# TypeError: '<' not supported between instances of 'datetime.date' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 find_next_trading_day(split_dates[0], 1)
#
# Cell In[53], line 9, in find_next_trading_day(x, day)
#       7 def find_next_trading_day(x: np.ndarray, day: int) -> int:
#       8     # Perform a binary search to find the index where the target day should be inserted
# ----> 9     idx = np.searchsorted(x, day, side='left')
#      11     # If the index is within bounds, return the next day, otherwise wrap around
#      12     if idx < len(x):
#
# File ~/Projects/best-day-to-save/.venv/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:1471, in searchsorted(a, v, side, sorter)
#    1402 @array_function_dispatch(_searchsorted_dispatcher)
#    1403 def searchsorted(a, v, side='left', sorter=None):
#    1404     """
#    1405     Find indices where elements should be inserted to maintain order.
#    1406
#    (...)
#    1469
#    1470     """
# -> 1471     return _wrapfunc(a, 'searchsorted', v, side=side, sorter=sorter)
#
# File ~/Projects/best-day-to-save/.venv/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:66, in _wrapfunc(obj, method, *args, **kwds)
#      57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
# ---> 66     return _wrapit(obj, method, *args, **kwds)
#
# File ~/Projects/best-day-to-save/.venv/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:46, in _wrapit(obj, method, *args, **kwds)
#      43 # As this already tried the method, subok is maybe quite reasonable here
#      44 # but this follows what was done before. TODO: revisit this.
#      45 arr, = conv.as_arrays(subok=False)
# ---> 46 result = getattr(arr, method)(*args, **kwds)
#      48 return conv.wrap(result, to_scalar=False)
#
# TypeError: '<' not supported between instances of 'datetime.date' and 'int'

# %%
import numpy as np

# Assuming dates is a 1D array of dates
dates = np.array([...])  # Replace with your actual dates array

# Define the new shape, for example, reshape to 2D array with 3 columns
new_shape = (len(dates) // 3, 3)

# Reshape the dates array
reshaped_dates = dates.reshape(new_shape)

print(reshaped_dates)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 np.array(split_dates).shape
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (633,) + inhomogeneous part.

# %%
dates_by_month
# Out:
# {datetime.date(1972, 1, 3): array([datetime.date(1972, 1, 3)], dtype=object),
#  datetime.date(1972, 1, 4): array([datetime.date(1972, 1, 4)], dtype=object),
#  datetime.date(1972, 1, 5): array([datetime.date(1972, 1, 5)], dtype=object),
#  datetime.date(1972, 1, 6): array([datetime.date(1972, 1, 6)], dtype=object),
#  datetime.date(1972, 1, 7): array([datetime.date(1972, 1, 7)], dtype=object),
#  datetime.date(1972, 1, 10): array([datetime.date(1972, 1, 10)], dtype=object),
#  datetime.date(1972, 1, 11): array([datetime.date(1972, 1, 11)], dtype=object),
#  datetime.date(1972, 1, 12): array([datetime.date(1972, 1, 12)], dtype=object),
#  datetime.date(1972, 1, 13): array([datetime.date(1972, 1, 13)], dtype=object),
#  datetime.date(1972, 1, 14): array([datetime.date(1972, 1, 14)], dtype=object),
#  datetime.date(1972, 1, 17): array([datetime.date(1972, 1, 17)], dtype=object),
#  datetime.date(1972, 1, 18): array([datetime.date(1972, 1, 18)], dtype=object),
#  datetime.date(1972, 1, 19): array([datetime.date(1972, 1, 19)], dtype=object),
#  datetime.date(1972, 1, 20): array([datetime.date(1972, 1, 20)], dtype=object),
#  datetime.date(1972, 1, 21): array([datetime.date(1972, 1, 21)], dtype=object),
#  datetime.date(1972, 1, 24): array([datetime.date(1972, 1, 24)], dtype=object),
#  datetime.date(1972, 1, 25): array([datetime.date(1972, 1, 25)], dtype=object),
#  datetime.date(1972, 1, 26): array([datetime.date(1972, 1, 26)], dtype=object),
#  datetime.date(1972, 1, 27): array([datetime.date(1972, 1, 27)], dtype=object),
#  datetime.date(1972, 1, 28): array([datetime.date(1972, 1, 28)], dtype=object),
#  datetime.date(1972, 1, 31): array([datetime.date(1972, 1, 31)], dtype=object),
#  datetime.date(1972, 2, 1): array([datetime.date(1972, 2, 1)], dtype=object),
#  datetime.date(1972, 2, 2): array([datetime.date(1972, 2, 2)], dtype=object),
#  datetime.date(1972, 2, 3): array([datetime.date(1972, 2, 3)], dtype=object),
#  datetime.date(1972, 2, 4): array([datetime.date(1972, 2, 4)], dtype=object),
#  datetime.date(1972, 2, 7): array([datetime.date(1972, 2, 7)], dtype=object),
#  datetime.date(1972, 2, 8): array([datetime.date(1972, 2, 8)], dtype=object),
#  datetime.date(1972, 2, 9): array([datetime.date(1972, 2, 9)], dtype=object),
#  datetime.date(1972, 2, 10): array([datetime.date(1972, 2, 10)], dtype=object),
#  datetime.date(1972, 2, 11): array([datetime.date(1972, 2, 11)], dtype=object),
#  datetime.date(1972, 2, 14): array([datetime.date(1972, 2, 14)], dtype=object),
#  datetime.date(1972, 2, 15): array([datetime.date(1972, 2, 15)], dtype=object),
#  datetime.date(1972, 2, 16): array([datetime.date(1972, 2, 16)], dtype=object),
#  datetime.date(1972, 2, 17): array([datetime.date(1972, 2, 17)], dtype=object),
#  datetime.date(1972, 2, 18): array([datetime.date(1972, 2, 18)], dtype=object),
#  datetime.date(1972, 2, 21): array([datetime.date(1972, 2, 21)], dtype=object),
#  datetime.date(1972, 2, 22): array([datetime.date(1972, 2, 22)], dtype=object),
#  datetime.date(1972, 2, 23): array([datetime.date(1972, 2, 23)], dtype=object),
#  datetime.date(1972, 2, 24): array([datetime.date(1972, 2, 24)], dtype=object),
#  datetime.date(1972, 2, 25): array([datetime.date(1972, 2, 25)], dtype=object),
#  datetime.date(1972, 2, 28): array([datetime.date(1972, 2, 28)], dtype=object),
#  datetime.date(1972, 2, 29): array([datetime.date(1972, 2, 29)], dtype=object),
#  datetime.date(1972, 3, 1): array([datetime.date(1972, 3, 1)], dtype=object),
#  datetime.date(1972, 3, 2): array([datetime.date(1972, 3, 2)], dtype=object),
#  datetime.date(1972, 3, 3): array([datetime.date(1972, 3, 3)], dtype=object),
#  datetime.date(1972, 3, 6): array([datetime.date(1972, 3, 6)], dtype=object),
#  datetime.date(1972, 3, 7): array([datetime.date(1972, 3, 7)], dtype=object),
#  datetime.date(1972, 3, 8): array([datetime.date(1972, 3, 8)], dtype=object),
#  datetime.date(1972, 3, 9): array([datetime.date(1972, 3, 9)], dtype=object),
#  datetime.date(1972, 3, 10): array([datetime.date(1972, 3, 10)], dtype=object),
#  datetime.date(1972, 3, 13): array([datetime.date(1972, 3, 13)], dtype=object),
#  datetime.date(1972, 3, 14): array([datetime.date(1972, 3, 14)], dtype=object),
#  datetime.date(1972, 3, 15): array([datetime.date(1972, 3, 15)], dtype=object),
#  datetime.date(1972, 3, 16): array([datetime.date(1972, 3, 16)], dtype=object),
#  datetime.date(1972, 3, 17): array([datetime.date(1972, 3, 17)], dtype=object),
#  datetime.date(1972, 3, 20): array([datetime.date(1972, 3, 20)], dtype=object),
#  datetime.date(1972, 3, 21): array([datetime.date(1972, 3, 21)], dtype=object),
#  datetime.date(1972, 3, 22): array([datetime.date(1972, 3, 22)], dtype=object),
#  datetime.date(1972, 3, 23): array([datetime.date(1972, 3, 23)], dtype=object),
#  datetime.date(1972, 3, 24): array([datetime.date(1972, 3, 24)], dtype=object),
#  datetime.date(1972, 3, 27): array([datetime.date(1972, 3, 27)], dtype=object),
#  datetime.date(1972, 3, 28): array([datetime.date(1972, 3, 28)], dtype=object),
#  datetime.date(1972, 3, 29): array([datetime.date(1972, 3, 29)], dtype=object),
#  datetime.date(1972, 3, 30): array([datetime.date(1972, 3, 30)], dtype=object),
#  datetime.date(1972, 3, 31): array([datetime.date(1972, 3, 31)], dtype=object),
#  datetime.date(1972, 4, 3): array([datetime.date(1972, 4, 3)], dtype=object),
#  datetime.date(1972, 4, 4): array([datetime.date(1972, 4, 4)], dtype=object),
#  datetime.date(1972, 4, 5): array([datetime.date(1972, 4, 5)], dtype=object),
#  datetime.date(1972, 4, 6): array([datetime.date(1972, 4, 6)], dtype=object),
#  datetime.date(1972, 4, 7): array([datetime.date(1972, 4, 7)], dtype=object),
#  datetime.date(1972, 4, 10): array([datetime.date(1972, 4, 10)], dtype=object),
#  datetime.date(1972, 4, 11): array([datetime.date(1972, 4, 11)], dtype=object),
#  datetime.date(1972, 4, 12): array([datetime.date(1972, 4, 12)], dtype=object),
#  datetime.date(1972, 4, 13): array([datetime.date(1972, 4, 13)], dtype=object),
#  datetime.date(1972, 4, 14): array([datetime.date(1972, 4, 14)], dtype=object),
#  datetime.date(1972, 4, 17): array([datetime.date(1972, 4, 17)], dtype=object),
#  datetime.date(1972, 4, 18): array([datetime.date(1972, 4, 18)], dtype=object),
#  datetime.date(1972, 4, 19): array([datetime.date(1972, 4, 19)], dtype=object),
#  datetime.date(1972, 4, 20): array([datetime.date(1972, 4, 20)], dtype=object),
#  datetime.date(1972, 4, 21): array([datetime.date(1972, 4, 21)], dtype=object),
#  datetime.date(1972, 4, 24): array([datetime.date(1972, 4, 24)], dtype=object),
#  datetime.date(1972, 4, 25): array([datetime.date(1972, 4, 25)], dtype=object),
#  datetime.date(1972, 4, 26): array([datetime.date(1972, 4, 26)], dtype=object),
#  datetime.date(1972, 4, 27): array([datetime.date(1972, 4, 27)], dtype=object),
#  datetime.date(1972, 4, 28): array([datetime.date(1972, 4, 28)], dtype=object),
#  datetime.date(1972, 5, 1): array([datetime.date(1972, 5, 1)], dtype=object),
#  datetime.date(1972, 5, 2): array([datetime.date(1972, 5, 2)], dtype=object),
#  datetime.date(1972, 5, 3): array([datetime.date(1972, 5, 3)], dtype=object),
#  datetime.date(1972, 5, 4): array([datetime.date(1972, 5, 4)], dtype=object),
#  datetime.date(1972, 5, 5): array([datetime.date(1972, 5, 5)], dtype=object),
#  datetime.date(1972, 5, 8): array([datetime.date(1972, 5, 8)], dtype=object),
#  datetime.date(1972, 5, 9): array([datetime.date(1972, 5, 9)], dtype=object),
#  datetime.date(1972, 5, 10): array([datetime.date(1972, 5, 10)], dtype=object),
#  datetime.date(1972, 5, 11): array([datetime.date(1972, 5, 11)], dtype=object),
#  datetime.date(1972, 5, 12): array([datetime.date(1972, 5, 12)], dtype=object),
#  datetime.date(1972, 5, 15): array([datetime.date(1972, 5, 15)], dtype=object),
#  datetime.date(1972, 5, 16): array([datetime.date(1972, 5, 16)], dtype=object),
#  datetime.date(1972, 5, 17): array([datetime.date(1972, 5, 17)], dtype=object),
#  datetime.date(1972, 5, 18): array([datetime.date(1972, 5, 18)], dtype=object),
#  datetime.date(1972, 5, 19): array([datetime.date(1972, 5, 19)], dtype=object),
#  datetime.date(1972, 5, 22): array([datetime.date(1972, 5, 22)], dtype=object),
#  datetime.date(1972, 5, 23): array([datetime.date(1972, 5, 23)], dtype=object),
#  datetime.date(1972, 5, 24): array([datetime.date(1972, 5, 24)], dtype=object),
#  datetime.date(1972, 5, 25): array([datetime.date(1972, 5, 25)], dtype=object),
#  datetime.date(1972, 5, 26): array([datetime.date(1972, 5, 26)], dtype=object),
#  datetime.date(1972, 5, 29): array([datetime.date(1972, 5, 29)], dtype=object),
#  datetime.date(1972, 5, 30): array([datetime.date(1972, 5, 30)], dtype=object),
#  datetime.date(1972, 5, 31): array([datetime.date(1972, 5, 31)], dtype=object),
#  datetime.date(1972, 6, 1): array([datetime.date(1972, 6, 1)], dtype=object),
#  datetime.date(1972, 6, 2): array([datetime.date(1972, 6, 2)], dtype=object),
#  datetime.date(1972, 6, 5): array([datetime.date(1972, 6, 5)], dtype=object),
#  datetime.date(1972, 6, 6): array([datetime.date(1972, 6, 6)], dtype=object),
#  datetime.date(1972, 6, 7): array([datetime.date(1972, 6, 7)], dtype=object),
#  datetime.date(1972, 6, 8): array([datetime.date(1972, 6, 8)], dtype=object),
#  datetime.date(1972, 6, 9): array([datetime.date(1972, 6, 9)], dtype=object),
#  datetime.date(1972, 6, 12): array([datetime.date(1972, 6, 12)], dtype=object),
#  datetime.date(1972, 6, 13): array([datetime.date(1972, 6, 13)], dtype=object),
#  datetime.date(1972, 6, 14): array([datetime.date(1972, 6, 14)], dtype=object),
#  datetime.date(1972, 6, 15): array([datetime.date(1972, 6, 15)], dtype=object),
#  datetime.date(1972, 6, 16): array([datetime.date(1972, 6, 16)], dtype=object),
#  datetime.date(1972, 6, 19): array([datetime.date(1972, 6, 19)], dtype=object),
#  datetime.date(1972, 6, 20): array([datetime.date(1972, 6, 20)], dtype=object),
#  datetime.date(1972, 6, 21): array([datetime.date(1972, 6, 21)], dtype=object),
#  datetime.date(1972, 6, 22): array([datetime.date(1972, 6, 22)], dtype=object),
#  datetime.date(1972, 6, 23): array([datetime.date(1972, 6, 23)], dtype=object),
#  datetime.date(1972, 6, 26): array([datetime.date(1972, 6, 26)], dtype=object),
#  datetime.date(1972, 6, 27): array([datetime.date(1972, 6, 27)], dtype=object),
#  datetime.date(1972, 6, 28): array([datetime.date(1972, 6, 28)], dtype=object),
#  datetime.date(1972, 6, 29): array([datetime.date(1972, 6, 29)], dtype=object),
#  datetime.date(1972, 6, 30): array([datetime.date(1972, 6, 30)], dtype=object),
#  datetime.date(1972, 7, 3): array([datetime.date(1972, 7, 3)], dtype=object),
#  datetime.date(1972, 7, 4): array([datetime.date(1972, 7, 4)], dtype=object),
#  datetime.date(1972, 7, 5): array([datetime.date(1972, 7, 5)], dtype=object),
#  datetime.date(1972, 7, 6): array([datetime.date(1972, 7, 6)], dtype=object),
#  datetime.date(1972, 7, 7): array([datetime.date(1972, 7, 7)], dtype=object),
#  datetime.date(1972, 7, 10): array([datetime.date(1972, 7, 10)], dtype=object),
#  datetime.date(1972, 7, 11): array([datetime.date(1972, 7, 11)], dtype=object),
#  datetime.date(1972, 7, 12): array([datetime.date(1972, 7, 12)], dtype=object),
#  datetime.date(1972, 7, 13): array([datetime.date(1972, 7, 13)], dtype=object),
#  datetime.date(1972, 7, 14): array([datetime.date(1972, 7, 14)], dtype=object),
#  datetime.date(1972, 7, 17): array([datetime.date(1972, 7, 17)], dtype=object),
#  datetime.date(1972, 7, 18): array([datetime.date(1972, 7, 18)], dtype=object),
#  datetime.date(1972, 7, 19): array([datetime.date(1972, 7, 19)], dtype=object),
#  datetime.date(1972, 7, 20): array([datetime.date(1972, 7, 20)], dtype=object),
#  datetime.date(1972, 7, 21): array([datetime.date(1972, 7, 21)], dtype=object),
#  datetime.date(1972, 7, 24): array([datetime.date(1972, 7, 24)], dtype=object),
#  datetime.date(1972, 7, 25): array([datetime.date(1972, 7, 25)], dtype=object),
#  datetime.date(1972, 7, 26): array([datetime.date(1972, 7, 26)], dtype=object),
#  datetime.date(1972, 7, 27): array([datetime.date(1972, 7, 27)], dtype=object),
#  datetime.date(1972, 7, 28): array([datetime.date(1972, 7, 28)], dtype=object),
#  datetime.date(1972, 7, 31): array([datetime.date(1972, 7, 31)], dtype=object),
#  datetime.date(1972, 8, 1): array([datetime.date(1972, 8, 1)], dtype=object),
#  datetime.date(1972, 8, 2): array([datetime.date(1972, 8, 2)], dtype=object),
#  datetime.date(1972, 8, 3): array([datetime.date(1972, 8, 3)], dtype=object),
#  datetime.date(1972, 8, 4): array([datetime.date(1972, 8, 4)], dtype=object),
#  datetime.date(1972, 8, 7): array([datetime.date(1972, 8, 7)], dtype=object),
#  datetime.date(1972, 8, 8): array([datetime.date(1972, 8, 8)], dtype=object),
#  datetime.date(1972, 8, 9): array([datetime.date(1972, 8, 9)], dtype=object),
#  datetime.date(1972, 8, 10): array([datetime.date(1972, 8, 10)], dtype=object),
#  datetime.date(1972, 8, 11): array([datetime.date(1972, 8, 11)], dtype=object),
#  datetime.date(1972, 8, 14): array([datetime.date(1972, 8, 14)], dtype=object),
#  datetime.date(1972, 8, 15): array([datetime.date(1972, 8, 15)], dtype=object),
#  datetime.date(1972, 8, 16): array([datetime.date(1972, 8, 16)], dtype=object),
#  datetime.date(1972, 8, 17): array([datetime.date(1972, 8, 17)], dtype=object),
#  datetime.date(1972, 8, 18): array([datetime.date(1972, 8, 18)], dtype=object),
#  datetime.date(1972, 8, 21): array([datetime.date(1972, 8, 21)], dtype=object),
#  datetime.date(1972, 8, 22): array([datetime.date(1972, 8, 22)], dtype=object),
#  datetime.date(1972, 8, 23): array([datetime.date(1972, 8, 23)], dtype=object),
#  datetime.date(1972, 8, 24): array([datetime.date(1972, 8, 24)], dtype=object),
#  datetime.date(1972, 8, 25): array([datetime.date(1972, 8, 25)], dtype=object),
#  datetime.date(1972, 8, 28): array([datetime.date(1972, 8, 28)], dtype=object),
#  datetime.date(1972, 8, 29): array([datetime.date(1972, 8, 29)], dtype=object),
#  datetime.date(1972, 8, 30): array([datetime.date(1972, 8, 30)], dtype=object),
#  datetime.date(1972, 8, 31): array([datetime.date(1972, 8, 31)], dtype=object),
#  datetime.date(1972, 9, 1): array([datetime.date(1972, 9, 1)], dtype=object),
#  datetime.date(1972, 9, 4): array([datetime.date(1972, 9, 4)], dtype=object),
#  datetime.date(1972, 9, 5): array([datetime.date(1972, 9, 5)], dtype=object),
#  datetime.date(1972, 9, 6): array([datetime.date(1972, 9, 6)], dtype=object),
#  datetime.date(1972, 9, 7): array([datetime.date(1972, 9, 7)], dtype=object),
#  datetime.date(1972, 9, 8): array([datetime.date(1972, 9, 8)], dtype=object),
#  datetime.date(1972, 9, 11): array([datetime.date(1972, 9, 11)], dtype=object),
#  datetime.date(1972, 9, 12): array([datetime.date(1972, 9, 12)], dtype=object),
#  datetime.date(1972, 9, 13): array([datetime.date(1972, 9, 13)], dtype=object),
#  datetime.date(1972, 9, 14): array([datetime.date(1972, 9, 14)], dtype=object),
#  datetime.date(1972, 9, 15): array([datetime.date(1972, 9, 15)], dtype=object),
#  datetime.date(1972, 9, 18): array([datetime.date(1972, 9, 18)], dtype=object),
#  datetime.date(1972, 9, 19): array([datetime.date(1972, 9, 19)], dtype=object),
#  datetime.date(1972, 9, 20): array([datetime.date(1972, 9, 20)], dtype=object),
#  datetime.date(1972, 9, 21): array([datetime.date(1972, 9, 21)], dtype=object),
#  datetime.date(1972, 9, 22): array([datetime.date(1972, 9, 22)], dtype=object),
#  datetime.date(1972, 9, 25): array([datetime.date(1972, 9, 25)], dtype=object),
#  datetime.date(1972, 9, 26): array([datetime.date(1972, 9, 26)], dtype=object),
#  datetime.date(1972, 9, 27): array([datetime.date(1972, 9, 27)], dtype=object),
#  datetime.date(1972, 9, 28): array([datetime.date(1972, 9, 28)], dtype=object),
#  datetime.date(1972, 9, 29): array([datetime.date(1972, 9, 29)], dtype=object),
#  datetime.date(1972, 10, 2): array([datetime.date(1972, 10, 2)], dtype=object),
#  datetime.date(1972, 10, 3): array([datetime.date(1972, 10, 3)], dtype=object),
#  datetime.date(1972, 10, 4): array([datetime.date(1972, 10, 4)], dtype=object),
#  datetime.date(1972, 10, 5): array([datetime.date(1972, 10, 5)], dtype=object),
#  datetime.date(1972, 10, 6): array([datetime.date(1972, 10, 6)], dtype=object),
#  datetime.date(1972, 10, 9): array([datetime.date(1972, 10, 9)], dtype=object),
#  datetime.date(1972, 10, 10): array([datetime.date(1972, 10, 10)], dtype=object),
#  datetime.date(1972, 10, 11): array([datetime.date(1972, 10, 11)], dtype=object),
#  datetime.date(1972, 10, 12): array([datetime.date(1972, 10, 12)], dtype=object),
#  datetime.date(1972, 10, 13): array([datetime.date(1972, 10, 13)], dtype=object),
#  datetime.date(1972, 10, 16): array([datetime.date(1972, 10, 16)], dtype=object),
#  datetime.date(1972, 10, 17): array([datetime.date(1972, 10, 17)], dtype=object),
#  datetime.date(1972, 10, 18): array([datetime.date(1972, 10, 18)], dtype=object),
#  datetime.date(1972, 10, 19): array([datetime.date(1972, 10, 19)], dtype=object),
#  datetime.date(1972, 10, 20): array([datetime.date(1972, 10, 20)], dtype=object),
#  datetime.date(1972, 10, 23): array([datetime.date(1972, 10, 23)], dtype=object),
#  datetime.date(1972, 10, 24): array([datetime.date(1972, 10, 24)], dtype=object),
#  datetime.date(1972, 10, 25): array([datetime.date(1972, 10, 25)], dtype=object),
#  datetime.date(1972, 10, 26): array([datetime.date(1972, 10, 26)], dtype=object),
#  datetime.date(1972, 10, 27): array([datetime.date(1972, 10, 27)], dtype=object),
#  datetime.date(1972, 10, 30): array([datetime.date(1972, 10, 30)], dtype=object),
#  datetime.date(1972, 10, 31): array([datetime.date(1972, 10, 31)], dtype=object),
#  datetime.date(1972, 11, 1): array([datetime.date(1972, 11, 1)], dtype=object),
#  datetime.date(1972, 11, 2): array([datetime.date(1972, 11, 2)], dtype=object),
#  datetime.date(1972, 11, 3): array([datetime.date(1972, 11, 3)], dtype=object),
#  datetime.date(1972, 11, 6): array([datetime.date(1972, 11, 6)], dtype=object),
#  datetime.date(1972, 11, 7): array([datetime.date(1972, 11, 7)], dtype=object),
#  datetime.date(1972, 11, 8): array([datetime.date(1972, 11, 8)], dtype=object),
#  datetime.date(1972, 11, 9): array([datetime.date(1972, 11, 9)], dtype=object),
#  datetime.date(1972, 11, 10): array([datetime.date(1972, 11, 10)], dtype=object),
#  datetime.date(1972, 11, 13): array([datetime.date(1972, 11, 13)], dtype=object),
#  datetime.date(1972, 11, 14): array([datetime.date(1972, 11, 14)], dtype=object),
#  datetime.date(1972, 11, 15): array([datetime.date(1972, 11, 15)], dtype=object),
#  datetime.date(1972, 11, 16): array([datetime.date(1972, 11, 16)], dtype=object),
#  datetime.date(1972, 11, 17): array([datetime.date(1972, 11, 17)], dtype=object),
#  datetime.date(1972, 11, 20): array([datetime.date(1972, 11, 20)], dtype=object),
#  datetime.date(1972, 11, 21): array([datetime.date(1972, 11, 21)], dtype=object),
#  datetime.date(1972, 11, 22): array([datetime.date(1972, 11, 22)], dtype=object),
#  datetime.date(1972, 11, 23): array([datetime.date(1972, 11, 23)], dtype=object),
#  datetime.date(1972, 11, 24): array([datetime.date(1972, 11, 24)], dtype=object),
#  datetime.date(1972, 11, 27): array([datetime.date(1972, 11, 27)], dtype=object),
#  datetime.date(1972, 11, 28): array([datetime.date(1972, 11, 28)], dtype=object),
#  datetime.date(1972, 11, 29): array([datetime.date(1972, 11, 29)], dtype=object),
#  datetime.date(1972, 11, 30): array([datetime.date(1972, 11, 30)], dtype=object),
#  datetime.date(1972, 12, 1): array([datetime.date(1972, 12, 1)], dtype=object),
#  datetime.date(1972, 12, 4): array([datetime.date(1972, 12, 4)], dtype=object),
#  datetime.date(1972, 12, 5): array([datetime.date(1972, 12, 5)], dtype=object),
#  datetime.date(1972, 12, 6): array([datetime.date(1972, 12, 6)], dtype=object),
#  datetime.date(1972, 12, 7): array([datetime.date(1972, 12, 7)], dtype=object),
#  datetime.date(1972, 12, 8): array([datetime.date(1972, 12, 8)], dtype=object),
#  datetime.date(1972, 12, 11): array([datetime.date(1972, 12, 11)], dtype=object),
#  datetime.date(1972, 12, 12): array([datetime.date(1972, 12, 12)], dtype=object),
#  datetime.date(1972, 12, 13): array([datetime.date(1972, 12, 13)], dtype=object),
#  datetime.date(1972, 12, 14): array([datetime.date(1972, 12, 14)], dtype=object),
#  datetime.date(1972, 12, 15): array([datetime.date(1972, 12, 15)], dtype=object),
#  datetime.date(1972, 12, 18): array([datetime.date(1972, 12, 18)], dtype=object),
#  datetime.date(1972, 12, 19): array([datetime.date(1972, 12, 19)], dtype=object),
#  datetime.date(1972, 12, 20): array([datetime.date(1972, 12, 20)], dtype=object),
#  datetime.date(1972, 12, 21): array([datetime.date(1972, 12, 21)], dtype=object),
#  datetime.date(1972, 12, 22): array([datetime.date(1972, 12, 22)], dtype=object),
#  datetime.date(1972, 12, 26): array([datetime.date(1972, 12, 26)], dtype=object),
#  datetime.date(1972, 12, 27): array([datetime.date(1972, 12, 27)], dtype=object),
#  datetime.date(1972, 12, 28): array([datetime.date(1972, 12, 28)], dtype=object),
#  datetime.date(1972, 12, 29): array([datetime.date(1972, 12, 29)], dtype=object),
#  datetime.date(1973, 1, 2): array([datetime.date(1973, 1, 2)], dtype=object),
#  datetime.date(1973, 1, 3): array([datetime.date(1973, 1, 3)], dtype=object),
#  datetime.date(1973, 1, 4): array([datetime.date(1973, 1, 4)], dtype=object),
#  datetime.date(1973, 1, 5): array([datetime.date(1973, 1, 5)], dtype=object),
#  datetime.date(1973, 1, 8): array([datetime.date(1973, 1, 8)], dtype=object),
#  datetime.date(1973, 1, 9): array([datetime.date(1973, 1, 9)], dtype=object),
#  datetime.date(1973, 1, 10): array([datetime.date(1973, 1, 10)], dtype=object),
#  datetime.date(1973, 1, 11): array([datetime.date(1973, 1, 11)], dtype=object),
#  datetime.date(1973, 1, 12): array([datetime.date(1973, 1, 12)], dtype=object),
#  datetime.date(1973, 1, 15): array([datetime.date(1973, 1, 15)], dtype=object),
#  datetime.date(1973, 1, 16): array([datetime.date(1973, 1, 16)], dtype=object),
#  datetime.date(1973, 1, 17): array([datetime.date(1973, 1, 17)], dtype=object),
#  datetime.date(1973, 1, 18): array([datetime.date(1973, 1, 18)], dtype=object),
#  datetime.date(1973, 1, 19): array([datetime.date(1973, 1, 19)], dtype=object),
#  datetime.date(1973, 1, 22): array([datetime.date(1973, 1, 22)], dtype=object),
#  datetime.date(1973, 1, 23): array([datetime.date(1973, 1, 23)], dtype=object),
#  datetime.date(1973, 1, 24): array([datetime.date(1973, 1, 24)], dtype=object),
#  datetime.date(1973, 1, 25): array([datetime.date(1973, 1, 25)], dtype=object),
#  datetime.date(1973, 1, 26): array([datetime.date(1973, 1, 26)], dtype=object),
#  datetime.date(1973, 1, 29): array([datetime.date(1973, 1, 29)], dtype=object),
#  datetime.date(1973, 1, 30): array([datetime.date(1973, 1, 30)], dtype=object),
#  datetime.date(1973, 1, 31): array([datetime.date(1973, 1, 31)], dtype=object),
#  datetime.date(1973, 2, 1): array([datetime.date(1973, 2, 1)], dtype=object),
#  datetime.date(1973, 2, 2): array([datetime.date(1973, 2, 2)], dtype=object),
#  datetime.date(1973, 2, 5): array([datetime.date(1973, 2, 5)], dtype=object),
#  datetime.date(1973, 2, 6): array([datetime.date(1973, 2, 6)], dtype=object),
#  datetime.date(1973, 2, 7): array([datetime.date(1973, 2, 7)], dtype=object),
#  datetime.date(1973, 2, 8): array([datetime.date(1973, 2, 8)], dtype=object),
#  datetime.date(1973, 2, 9): array([datetime.date(1973, 2, 9)], dtype=object),
#  datetime.date(1973, 2, 12): array([datetime.date(1973, 2, 12)], dtype=object),
#  datetime.date(1973, 2, 13): array([datetime.date(1973, 2, 13)], dtype=object),
#  datetime.date(1973, 2, 14): array([datetime.date(1973, 2, 14)], dtype=object),
#  datetime.date(1973, 2, 15): array([datetime.date(1973, 2, 15)], dtype=object),
#  datetime.date(1973, 2, 16): array([datetime.date(1973, 2, 16)], dtype=object),
#  datetime.date(1973, 2, 19): array([datetime.date(1973, 2, 19)], dtype=object),
#  datetime.date(1973, 2, 20): array([datetime.date(1973, 2, 20)], dtype=object),
#  datetime.date(1973, 2, 21): array([datetime.date(1973, 2, 21)], dtype=object),
#  datetime.date(1973, 2, 22): array([datetime.date(1973, 2, 22)], dtype=object),
#  datetime.date(1973, 2, 23): array([datetime.date(1973, 2, 23)], dtype=object),
#  datetime.date(1973, 2, 26): array([datetime.date(1973, 2, 26)], dtype=object),
#  datetime.date(1973, 2, 27): array([datetime.date(1973, 2, 27)], dtype=object),
#  datetime.date(1973, 2, 28): array([datetime.date(1973, 2, 28)], dtype=object),
#  datetime.date(1973, 3, 1): array([datetime.date(1973, 3, 1)], dtype=object),
#  datetime.date(1973, 3, 2): array([datetime.date(1973, 3, 2)], dtype=object),
#  datetime.date(1973, 3, 5): array([datetime.date(1973, 3, 5)], dtype=object),
#  datetime.date(1973, 3, 6): array([datetime.date(1973, 3, 6)], dtype=object),
#  datetime.date(1973, 3, 7): array([datetime.date(1973, 3, 7)], dtype=object),
#  datetime.date(1973, 3, 8): array([datetime.date(1973, 3, 8)], dtype=object),
#  datetime.date(1973, 3, 9): array([datetime.date(1973, 3, 9)], dtype=object),
#  datetime.date(1973, 3, 12): array([datetime.date(1973, 3, 12)], dtype=object),
#  datetime.date(1973, 3, 13): array([datetime.date(1973, 3, 13)], dtype=object),
#  datetime.date(1973, 3, 14): array([datetime.date(1973, 3, 14)], dtype=object),
#  datetime.date(1973, 3, 15): array([datetime.date(1973, 3, 15)], dtype=object),
#  datetime.date(1973, 3, 16): array([datetime.date(1973, 3, 16)], dtype=object),
#  datetime.date(1973, 3, 19): array([datetime.date(1973, 3, 19)], dtype=object),
#  datetime.date(1973, 3, 20): array([datetime.date(1973, 3, 20)], dtype=object),
#  datetime.date(1973, 3, 21): array([datetime.date(1973, 3, 21)], dtype=object),
#  datetime.date(1973, 3, 22): array([datetime.date(1973, 3, 22)], dtype=object),
#  datetime.date(1973, 3, 23): array([datetime.date(1973, 3, 23)], dtype=object),
#  datetime.date(1973, 3, 26): array([datetime.date(1973, 3, 26)], dtype=object),
#  datetime.date(1973, 3, 27): array([datetime.date(1973, 3, 27)], dtype=object),
#  datetime.date(1973, 3, 28): array([datetime.date(1973, 3, 28)], dtype=object),
#  datetime.date(1973, 3, 29): array([datetime.date(1973, 3, 29)], dtype=object),
#  datetime.date(1973, 3, 30): array([datetime.date(1973, 3, 30)], dtype=object),
#  datetime.date(1973, 4, 2): array([datetime.date(1973, 4, 2)], dtype=object),
#  datetime.date(1973, 4, 3): array([datetime.date(1973, 4, 3)], dtype=object),
#  datetime.date(1973, 4, 4): array([datetime.date(1973, 4, 4)], dtype=object),
#  datetime.date(1973, 4, 5): array([datetime.date(1973, 4, 5)], dtype=object),
#  datetime.date(1973, 4, 6): array([datetime.date(1973, 4, 6)], dtype=object),
#  datetime.date(1973, 4, 9): array([datetime.date(1973, 4, 9)], dtype=object),
#  datetime.date(1973, 4, 10): array([datetime.date(1973, 4, 10)], dtype=object),
#  datetime.date(1973, 4, 11): array([datetime.date(1973, 4, 11)], dtype=object),
#  datetime.date(1973, 4, 12): array([datetime.date(1973, 4, 12)], dtype=object),
#  datetime.date(1973, 4, 13): array([datetime.date(1973, 4, 13)], dtype=object),
#  datetime.date(1973, 4, 16): array([datetime.date(1973, 4, 16)], dtype=object),
#  datetime.date(1973, 4, 17): array([datetime.date(1973, 4, 17)], dtype=object),
#  datetime.date(1973, 4, 18): array([datetime.date(1973, 4, 18)], dtype=object),
#  datetime.date(1973, 4, 19): array([datetime.date(1973, 4, 19)], dtype=object),
#  datetime.date(1973, 4, 20): array([datetime.date(1973, 4, 20)], dtype=object),
#  datetime.date(1973, 4, 23): array([datetime.date(1973, 4, 23)], dtype=object),
#  datetime.date(1973, 4, 24): array([datetime.date(1973, 4, 24)], dtype=object),
#  datetime.date(1973, 4, 25): array([datetime.date(1973, 4, 25)], dtype=object),
#  datetime.date(1973, 4, 26): array([datetime.date(1973, 4, 26)], dtype=object),
#  datetime.date(1973, 4, 27): array([datetime.date(1973, 4, 27)], dtype=object),
#  datetime.date(1973, 4, 30): array([datetime.date(1973, 4, 30)], dtype=object),
#  datetime.date(1973, 5, 1): array([datetime.date(1973, 5, 1)], dtype=object),
#  datetime.date(1973, 5, 2): array([datetime.date(1973, 5, 2)], dtype=object),
#  datetime.date(1973, 5, 3): array([datetime.date(1973, 5, 3)], dtype=object),
#  datetime.date(1973, 5, 4): array([datetime.date(1973, 5, 4)], dtype=object),
#  datetime.date(1973, 5, 7): array([datetime.date(1973, 5, 7)], dtype=object),
#  datetime.date(1973, 5, 8): array([datetime.date(1973, 5, 8)], dtype=object),
#  datetime.date(1973, 5, 9): array([datetime.date(1973, 5, 9)], dtype=object),
#  datetime.date(1973, 5, 10): array([datetime.date(1973, 5, 10)], dtype=object),
#  datetime.date(1973, 5, 11): array([datetime.date(1973, 5, 11)], dtype=object),
#  datetime.date(1973, 5, 14): array([datetime.date(1973, 5, 14)], dtype=object),
#  datetime.date(1973, 5, 15): array([datetime.date(1973, 5, 15)], dtype=object),
#  datetime.date(1973, 5, 16): array([datetime.date(1973, 5, 16)], dtype=object),
#  datetime.date(1973, 5, 17): array([datetime.date(1973, 5, 17)], dtype=object),
#  datetime.date(1973, 5, 18): array([datetime.date(1973, 5, 18)], dtype=object),
#  datetime.date(1973, 5, 21): array([datetime.date(1973, 5, 21)], dtype=object),
#  datetime.date(1973, 5, 22): array([datetime.date(1973, 5, 22)], dtype=object),
#  datetime.date(1973, 5, 23): array([datetime.date(1973, 5, 23)], dtype=object),
#  datetime.date(1973, 5, 24): array([datetime.date(1973, 5, 24)], dtype=object),
#  datetime.date(1973, 5, 25): array([datetime.date(1973, 5, 25)], dtype=object),
#  datetime.date(1973, 5, 28): array([datetime.date(1973, 5, 28)], dtype=object),
#  datetime.date(1973, 5, 29): array([datetime.date(1973, 5, 29)], dtype=object),
#  datetime.date(1973, 5, 30): array([datetime.date(1973, 5, 30)], dtype=object),
#  datetime.date(1973, 5, 31): array([datetime.date(1973, 5, 31)], dtype=object),
#  datetime.date(1973, 6, 1): array([datetime.date(1973, 6, 1)], dtype=object),
#  datetime.date(1973, 6, 4): array([datetime.date(1973, 6, 4)], dtype=object),
#  datetime.date(1973, 6, 5): array([datetime.date(1973, 6, 5)], dtype=object),
#  datetime.date(1973, 6, 6): array([datetime.date(1973, 6, 6)], dtype=object),
#  datetime.date(1973, 6, 7): array([datetime.date(1973, 6, 7)], dtype=object),
#  datetime.date(1973, 6, 8): array([datetime.date(1973, 6, 8)], dtype=object),
#  datetime.date(1973, 6, 11): array([datetime.date(1973, 6, 11)], dtype=object),
#  datetime.date(1973, 6, 12): array([datetime.date(1973, 6, 12)], dtype=object),
#  datetime.date(1973, 6, 13): array([datetime.date(1973, 6, 13)], dtype=object),
#  datetime.date(1973, 6, 14): array([datetime.date(1973, 6, 14)], dtype=object),
#  datetime.date(1973, 6, 15): array([datetime.date(1973, 6, 15)], dtype=object),
#  datetime.date(1973, 6, 18): array([datetime.date(1973, 6, 18)], dtype=object),
#  datetime.date(1973, 6, 19): array([datetime.date(1973, 6, 19)], dtype=object),
#  datetime.date(1973, 6, 20): array([datetime.date(1973, 6, 20)], dtype=object),
#  datetime.date(1973, 6, 21): array([datetime.date(1973, 6, 21)], dtype=object),
#  datetime.date(1973, 6, 22): array([datetime.date(1973, 6, 22)], dtype=object),
#  datetime.date(1973, 6, 25): array([datetime.date(1973, 6, 25)], dtype=object),
#  datetime.date(1973, 6, 26): array([datetime.date(1973, 6, 26)], dtype=object),
#  datetime.date(1973, 6, 27): array([datetime.date(1973, 6, 27)], dtype=object),
#  datetime.date(1973, 6, 28): array([datetime.date(1973, 6, 28)], dtype=object),
#  datetime.date(1973, 6, 29): array([datetime.date(1973, 6, 29)], dtype=object),
#  datetime.date(1973, 7, 2): array([datetime.date(1973, 7, 2)], dtype=object),
#  datetime.date(1973, 7, 3): array([datetime.date(1973, 7, 3)], dtype=object),
#  datetime.date(1973, 7, 4): array([datetime.date(1973, 7, 4)], dtype=object),
#  datetime.date(1973, 7, 5): array([datetime.date(1973, 7, 5)], dtype=object),
#  datetime.date(1973, 7, 6): array([datetime.date(1973, 7, 6)], dtype=object),
#  datetime.date(1973, 7, 9): array([datetime.date(1973, 7, 9)], dtype=object),
#  datetime.date(1973, 7, 10): array([datetime.date(1973, 7, 10)], dtype=object),
#  datetime.date(1973, 7, 11): array([datetime.date(1973, 7, 11)], dtype=object),
#  datetime.date(1973, 7, 12): array([datetime.date(1973, 7, 12)], dtype=object),
#  datetime.date(1973, 7, 13): array([datetime.date(1973, 7, 13)], dtype=object),
#  datetime.date(1973, 7, 16): array([datetime.date(1973, 7, 16)], dtype=object),
#  datetime.date(1973, 7, 17): array([datetime.date(1973, 7, 17)], dtype=object),
#  datetime.date(1973, 7, 18): array([datetime.date(1973, 7, 18)], dtype=object),
#  datetime.date(1973, 7, 19): array([datetime.date(1973, 7, 19)], dtype=object),
#  datetime.date(1973, 7, 20): array([datetime.date(1973, 7, 20)], dtype=object),
#  datetime.date(1973, 7, 23): array([datetime.date(1973, 7, 23)], dtype=object),
#  datetime.date(1973, 7, 24): array([datetime.date(1973, 7, 24)], dtype=object),
#  datetime.date(1973, 7, 25): array([datetime.date(1973, 7, 25)], dtype=object),
#  datetime.date(1973, 7, 26): array([datetime.date(1973, 7, 26)], dtype=object),
#  datetime.date(1973, 7, 27): array([datetime.date(1973, 7, 27)], dtype=object),
#  datetime.date(1973, 7, 30): array([datetime.date(1973, 7, 30)], dtype=object),
#  datetime.date(1973, 7, 31): array([datetime.date(1973, 7, 31)], dtype=object),
#  datetime.date(1973, 8, 1): array([datetime.date(1973, 8, 1)], dtype=object),
#  datetime.date(1973, 8, 2): array([datetime.date(1973, 8, 2)], dtype=object),
#  datetime.date(1973, 8, 3): array([datetime.date(1973, 8, 3)], dtype=object),
#  datetime.date(1973, 8, 6): array([datetime.date(1973, 8, 6)], dtype=object),
#  datetime.date(1973, 8, 7): array([datetime.date(1973, 8, 7)], dtype=object),
#  datetime.date(1973, 8, 8): array([datetime.date(1973, 8, 8)], dtype=object),
#  datetime.date(1973, 8, 9): array([datetime.date(1973, 8, 9)], dtype=object),
#  datetime.date(1973, 8, 10): array([datetime.date(1973, 8, 10)], dtype=object),
#  datetime.date(1973, 8, 13): array([datetime.date(1973, 8, 13)], dtype=object),
#  datetime.date(1973, 8, 14): array([datetime.date(1973, 8, 14)], dtype=object),
#  datetime.date(1973, 8, 15): array([datetime.date(1973, 8, 15)], dtype=object),
#  datetime.date(1973, 8, 16): array([datetime.date(1973, 8, 16)], dtype=object),
#  datetime.date(1973, 8, 17): array([datetime.date(1973, 8, 17)], dtype=object),
#  datetime.date(1973, 8, 20): array([datetime.date(1973, 8, 20)], dtype=object),
#  datetime.date(1973, 8, 21): array([datetime.date(1973, 8, 21)], dtype=object),
#  datetime.date(1973, 8, 22): array([datetime.date(1973, 8, 22)], dtype=object),
#  datetime.date(1973, 8, 23): array([datetime.date(1973, 8, 23)], dtype=object),
#  datetime.date(1973, 8, 24): array([datetime.date(1973, 8, 24)], dtype=object),
#  datetime.date(1973, 8, 27): array([datetime.date(1973, 8, 27)], dtype=object),
#  datetime.date(1973, 8, 28): array([datetime.date(1973, 8, 28)], dtype=object),
#  datetime.date(1973, 8, 29): array([datetime.date(1973, 8, 29)], dtype=object),
#  datetime.date(1973, 8, 30): array([datetime.date(1973, 8, 30)], dtype=object),
#  datetime.date(1973, 8, 31): array([datetime.date(1973, 8, 31)], dtype=object),
#  datetime.date(1973, 9, 3): array([datetime.date(1973, 9, 3)], dtype=object),
#  datetime.date(1973, 9, 4): array([datetime.date(1973, 9, 4)], dtype=object),
#  datetime.date(1973, 9, 5): array([datetime.date(1973, 9, 5)], dtype=object),
#  datetime.date(1973, 9, 6): array([datetime.date(1973, 9, 6)], dtype=object),
#  datetime.date(1973, 9, 7): array([datetime.date(1973, 9, 7)], dtype=object),
#  datetime.date(1973, 9, 10): array([datetime.date(1973, 9, 10)], dtype=object),
#  datetime.date(1973, 9, 11): array([datetime.date(1973, 9, 11)], dtype=object),
#  datetime.date(1973, 9, 12): array([datetime.date(1973, 9, 12)], dtype=object),
#  datetime.date(1973, 9, 13): array([datetime.date(1973, 9, 13)], dtype=object),
#  datetime.date(1973, 9, 14): array([datetime.date(1973, 9, 14)], dtype=object),
#  datetime.date(1973, 9, 17): array([datetime.date(1973, 9, 17)], dtype=object),
#  datetime.date(1973, 9, 18): array([datetime.date(1973, 9, 18)], dtype=object),
#  datetime.date(1973, 9, 19): array([datetime.date(1973, 9, 19)], dtype=object),
#  datetime.date(1973, 9, 20): array([datetime.date(1973, 9, 20)], dtype=object),
#  datetime.date(1973, 9, 21): array([datetime.date(1973, 9, 21)], dtype=object),
#  datetime.date(1973, 9, 24): array([datetime.date(1973, 9, 24)], dtype=object),
#  datetime.date(1973, 9, 25): array([datetime.date(1973, 9, 25)], dtype=object),
#  datetime.date(1973, 9, 26): array([datetime.date(1973, 9, 26)], dtype=object),
#  datetime.date(1973, 9, 27): array([datetime.date(1973, 9, 27)], dtype=object),
#  datetime.date(1973, 9, 28): array([datetime.date(1973, 9, 28)], dtype=object),
#  datetime.date(1973, 10, 1): array([datetime.date(1973, 10, 1)], dtype=object),
#  datetime.date(1973, 10, 2): array([datetime.date(1973, 10, 2)], dtype=object),
#  datetime.date(1973, 10, 3): array([datetime.date(1973, 10, 3)], dtype=object),
#  datetime.date(1973, 10, 4): array([datetime.date(1973, 10, 4)], dtype=object),
#  datetime.date(1973, 10, 5): array([datetime.date(1973, 10, 5)], dtype=object),
#  datetime.date(1973, 10, 8): array([datetime.date(1973, 10, 8)], dtype=object),
#  datetime.date(1973, 10, 9): array([datetime.date(1973, 10, 9)], dtype=object),
#  datetime.date(1973, 10, 10): array([datetime.date(1973, 10, 10)], dtype=object),
#  datetime.date(1973, 10, 11): array([datetime.date(1973, 10, 11)], dtype=object),
#  datetime.date(1973, 10, 12): array([datetime.date(1973, 10, 12)], dtype=object),
#  datetime.date(1973, 10, 15): array([datetime.date(1973, 10, 15)], dtype=object),
#  datetime.date(1973, 10, 16): array([datetime.date(1973, 10, 16)], dtype=object),
#  datetime.date(1973, 10, 17): array([datetime.date(1973, 10, 17)], dtype=object),
#  datetime.date(1973, 10, 18): array([datetime.date(1973, 10, 18)], dtype=object),
#  datetime.date(1973, 10, 19): array([datetime.date(1973, 10, 19)], dtype=object),
#  datetime.date(1973, 10, 22): array([datetime.date(1973, 10, 22)], dtype=object),
#  datetime.date(1973, 10, 23): array([datetime.date(1973, 10, 23)], dtype=object),
#  datetime.date(1973, 10, 24): array([datetime.date(1973, 10, 24)], dtype=object),
#  datetime.date(1973, 10, 25): array([datetime.date(1973, 10, 25)], dtype=object),
#  datetime.date(1973, 10, 26): array([datetime.date(1973, 10, 26)], dtype=object),
#  datetime.date(1973, 10, 29): array([datetime.date(1973, 10, 29)], dtype=object),
#  datetime.date(1973, 10, 30): array([datetime.date(1973, 10, 30)], dtype=object),
#  datetime.date(1973, 10, 31): array([datetime.date(1973, 10, 31)], dtype=object),
#  datetime.date(1973, 11, 1): array([datetime.date(1973, 11, 1)], dtype=object),
#  datetime.date(1973, 11, 2): array([datetime.date(1973, 11, 2)], dtype=object),
#  datetime.date(1973, 11, 5): array([datetime.date(1973, 11, 5)], dtype=object),
#  datetime.date(1973, 11, 6): array([datetime.date(1973, 11, 6)], dtype=object),
#  datetime.date(1973, 11, 7): array([datetime.date(1973, 11, 7)], dtype=object),
#  datetime.date(1973, 11, 8): array([datetime.date(1973, 11, 8)], dtype=object),
#  datetime.date(1973, 11, 9): array([datetime.date(1973, 11, 9)], dtype=object),
#  datetime.date(1973, 11, 12): array([datetime.date(1973, 11, 12)], dtype=object),
#  datetime.date(1973, 11, 13): array([datetime.date(1973, 11, 13)], dtype=object),
#  datetime.date(1973, 11, 14): array([datetime.date(1973, 11, 14)], dtype=object),
#  datetime.date(1973, 11, 15): array([datetime.date(1973, 11, 15)], dtype=object),
#  datetime.date(1973, 11, 16): array([datetime.date(1973, 11, 16)], dtype=object),
#  datetime.date(1973, 11, 19): array([datetime.date(1973, 11, 19)], dtype=object),
#  datetime.date(1973, 11, 20): array([datetime.date(1973, 11, 20)], dtype=object),
#  datetime.date(1973, 11, 21): array([datetime.date(1973, 11, 21)], dtype=object),
#  datetime.date(1973, 11, 22): array([datetime.date(1973, 11, 22)], dtype=object),
#  datetime.date(1973, 11, 23): array([datetime.date(1973, 11, 23)], dtype=object),
#  datetime.date(1973, 11, 26): array([datetime.date(1973, 11, 26)], dtype=object),
#  datetime.date(1973, 11, 27): array([datetime.date(1973, 11, 27)], dtype=object),
#  datetime.date(1973, 11, 28): array([datetime.date(1973, 11, 28)], dtype=object),
#  datetime.date(1973, 11, 29): array([datetime.date(1973, 11, 29)], dtype=object),
#  datetime.date(1973, 11, 30): array([datetime.date(1973, 11, 30)], dtype=object),
#  datetime.date(1973, 12, 3): array([datetime.date(1973, 12, 3)], dtype=object),
#  datetime.date(1973, 12, 4): array([datetime.date(1973, 12, 4)], dtype=object),
#  datetime.date(1973, 12, 5): array([datetime.date(1973, 12, 5)], dtype=object),
#  datetime.date(1973, 12, 6): array([datetime.date(1973, 12, 6)], dtype=object),
#  datetime.date(1973, 12, 7): array([datetime.date(1973, 12, 7)], dtype=object),
#  datetime.date(1973, 12, 10): array([datetime.date(1973, 12, 10)], dtype=object),
#  datetime.date(1973, 12, 11): array([datetime.date(1973, 12, 11)], dtype=object),
#  datetime.date(1973, 12, 12): array([datetime.date(1973, 12, 12)], dtype=object),
#  datetime.date(1973, 12, 13): array([datetime.date(1973, 12, 13)], dtype=object),
#  datetime.date(1973, 12, 14): array([datetime.date(1973, 12, 14)], dtype=object),
#  datetime.date(1973, 12, 17): array([datetime.date(1973, 12, 17)], dtype=object),
#  datetime.date(1973, 12, 18): array([datetime.date(1973, 12, 18)], dtype=object),
#  datetime.date(1973, 12, 19): array([datetime.date(1973, 12, 19)], dtype=object),
#  datetime.date(1973, 12, 20): array([datetime.date(1973, 12, 20)], dtype=object),
#  datetime.date(1973, 12, 21): array([datetime.date(1973, 12, 21)], dtype=object),
#  datetime.date(1973, 12, 24): array([datetime.date(1973, 12, 24)], dtype=object),
#  datetime.date(1973, 12, 26): array([datetime.date(1973, 12, 26)], dtype=object),
#  datetime.date(1973, 12, 27): array([datetime.date(1973, 12, 27)], dtype=object),
#  datetime.date(1973, 12, 28): array([datetime.date(1973, 12, 28)], dtype=object),
#  datetime.date(1973, 12, 31): array([datetime.date(1973, 12, 31)], dtype=object),
#  datetime.date(1974, 1, 2): array([datetime.date(1974, 1, 2)], dtype=object),
#  datetime.date(1974, 1, 3): array([datetime.date(1974, 1, 3)], dtype=object),
#  datetime.date(1974, 1, 4): array([datetime.date(1974, 1, 4)], dtype=object),
#  datetime.date(1974, 1, 7): array([datetime.date(1974, 1, 7)], dtype=object),
#  datetime.date(1974, 1, 8): array([datetime.date(1974, 1, 8)], dtype=object),
#  datetime.date(1974, 1, 9): array([datetime.date(1974, 1, 9)], dtype=object),
#  datetime.date(1974, 1, 10): array([datetime.date(1974, 1, 10)], dtype=object),
#  datetime.date(1974, 1, 11): array([datetime.date(1974, 1, 11)], dtype=object),
#  datetime.date(1974, 1, 14): array([datetime.date(1974, 1, 14)], dtype=object),
#  datetime.date(1974, 1, 15): array([datetime.date(1974, 1, 15)], dtype=object),
#  datetime.date(1974, 1, 16): array([datetime.date(1974, 1, 16)], dtype=object),
#  datetime.date(1974, 1, 17): array([datetime.date(1974, 1, 17)], dtype=object),
#  datetime.date(1974, 1, 18): array([datetime.date(1974, 1, 18)], dtype=object),
#  datetime.date(1974, 1, 21): array([datetime.date(1974, 1, 21)], dtype=object),
#  datetime.date(1974, 1, 22): array([datetime.date(1974, 1, 22)], dtype=object),
#  datetime.date(1974, 1, 23): array([datetime.date(1974, 1, 23)], dtype=object),
#  datetime.date(1974, 1, 24): array([datetime.date(1974, 1, 24)], dtype=object),
#  datetime.date(1974, 1, 25): array([datetime.date(1974, 1, 25)], dtype=object),
#  datetime.date(1974, 1, 28): array([datetime.date(1974, 1, 28)], dtype=object),
#  datetime.date(1974, 1, 29): array([datetime.date(1974, 1, 29)], dtype=object),
#  datetime.date(1974, 1, 30): array([datetime.date(1974, 1, 30)], dtype=object),
#  datetime.date(1974, 1, 31): array([datetime.date(1974, 1, 31)], dtype=object),
#  datetime.date(1974, 2, 1): array([datetime.date(1974, 2, 1)], dtype=object),
#  datetime.date(1974, 2, 4): array([datetime.date(1974, 2, 4)], dtype=object),
#  datetime.date(1974, 2, 5): array([datetime.date(1974, 2, 5)], dtype=object),
#  datetime.date(1974, 2, 6): array([datetime.date(1974, 2, 6)], dtype=object),
#  datetime.date(1974, 2, 7): array([datetime.date(1974, 2, 7)], dtype=object),
#  datetime.date(1974, 2, 8): array([datetime.date(1974, 2, 8)], dtype=object),
#  datetime.date(1974, 2, 11): array([datetime.date(1974, 2, 11)], dtype=object),
#  datetime.date(1974, 2, 12): array([datetime.date(1974, 2, 12)], dtype=object),
#  datetime.date(1974, 2, 13): array([datetime.date(1974, 2, 13)], dtype=object),
#  datetime.date(1974, 2, 14): array([datetime.date(1974, 2, 14)], dtype=object),
#  datetime.date(1974, 2, 15): array([datetime.date(1974, 2, 15)], dtype=object),
#  datetime.date(1974, 2, 18): array([datetime.date(1974, 2, 18)], dtype=object),
#  datetime.date(1974, 2, 19): array([datetime.date(1974, 2, 19)], dtype=object),
#  datetime.date(1974, 2, 20): array([datetime.date(1974, 2, 20)], dtype=object),
#  datetime.date(1974, 2, 21): array([datetime.date(1974, 2, 21)], dtype=object),
#  datetime.date(1974, 2, 22): array([datetime.date(1974, 2, 22)], dtype=object),
#  datetime.date(1974, 2, 25): array([datetime.date(1974, 2, 25)], dtype=object),
#  datetime.date(1974, 2, 26): array([datetime.date(1974, 2, 26)], dtype=object),
#  datetime.date(1974, 2, 27): array([datetime.date(1974, 2, 27)], dtype=object),
#  datetime.date(1974, 2, 28): array([datetime.date(1974, 2, 28)], dtype=object),
#  datetime.date(1974, 3, 1): array([datetime.date(1974, 3, 1)], dtype=object),
#  datetime.date(1974, 3, 4): array([datetime.date(1974, 3, 4)], dtype=object),
#  datetime.date(1974, 3, 5): array([datetime.date(1974, 3, 5)], dtype=object),
#  datetime.date(1974, 3, 6): array([datetime.date(1974, 3, 6)], dtype=object),
#  datetime.date(1974, 3, 7): array([datetime.date(1974, 3, 7)], dtype=object),
#  datetime.date(1974, 3, 8): array([datetime.date(1974, 3, 8)], dtype=object),
#  datetime.date(1974, 3, 11): array([datetime.date(1974, 3, 11)], dtype=object),
#  datetime.date(1974, 3, 12): array([datetime.date(1974, 3, 12)], dtype=object),
#  datetime.date(1974, 3, 13): array([datetime.date(1974, 3, 13)], dtype=object),
#  datetime.date(1974, 3, 14): array([datetime.date(1974, 3, 14)], dtype=object),
#  datetime.date(1974, 3, 15): array([datetime.date(1974, 3, 15)], dtype=object),
#  datetime.date(1974, 3, 18): array([datetime.date(1974, 3, 18)], dtype=object),
#  datetime.date(1974, 3, 19): array([datetime.date(1974, 3, 19)], dtype=object),
#  datetime.date(1974, 3, 20): array([datetime.date(1974, 3, 20)], dtype=object),
#  datetime.date(1974, 3, 21): array([datetime.date(1974, 3, 21)], dtype=object),
#  datetime.date(1974, 3, 22): array([datetime.date(1974, 3, 22)], dtype=object),
#  datetime.date(1974, 3, 25): array([datetime.date(1974, 3, 25)], dtype=object),
#  datetime.date(1974, 3, 26): array([datetime.date(1974, 3, 26)], dtype=object),
#  datetime.date(1974, 3, 27): array([datetime.date(1974, 3, 27)], dtype=object),
#  datetime.date(1974, 3, 28): array([datetime.date(1974, 3, 28)], dtype=object),
#  datetime.date(1974, 3, 29): array([datetime.date(1974, 3, 29)], dtype=object),
#  datetime.date(1974, 4, 1): array([datetime.date(1974, 4, 1)], dtype=object),
#  datetime.date(1974, 4, 2): array([datetime.date(1974, 4, 2)], dtype=object),
#  datetime.date(1974, 4, 3): array([datetime.date(1974, 4, 3)], dtype=object),
#  datetime.date(1974, 4, 4): array([datetime.date(1974, 4, 4)], dtype=object),
#  datetime.date(1974, 4, 5): array([datetime.date(1974, 4, 5)], dtype=object),
#  datetime.date(1974, 4, 8): array([datetime.date(1974, 4, 8)], dtype=object),
#  datetime.date(1974, 4, 9): array([datetime.date(1974, 4, 9)], dtype=object),
#  datetime.date(1974, 4, 10): array([datetime.date(1974, 4, 10)], dtype=object),
#  datetime.date(1974, 4, 11): array([datetime.date(1974, 4, 11)], dtype=object),
#  datetime.date(1974, 4, 12): array([datetime.date(1974, 4, 12)], dtype=object),
#  datetime.date(1974, 4, 15): array([datetime.date(1974, 4, 15)], dtype=object),
#  datetime.date(1974, 4, 16): array([datetime.date(1974, 4, 16)], dtype=object),
#  datetime.date(1974, 4, 17): array([datetime.date(1974, 4, 17)], dtype=object),
#  datetime.date(1974, 4, 18): array([datetime.date(1974, 4, 18)], dtype=object),
#  datetime.date(1974, 4, 19): array([datetime.date(1974, 4, 19)], dtype=object),
#  datetime.date(1974, 4, 22): array([datetime.date(1974, 4, 22)], dtype=object),
#  datetime.date(1974, 4, 23): array([datetime.date(1974, 4, 23)], dtype=object),
#  datetime.date(1974, 4, 24): array([datetime.date(1974, 4, 24)], dtype=object),
#  datetime.date(1974, 4, 25): array([datetime.date(1974, 4, 25)], dtype=object),
#  datetime.date(1974, 4, 26): array([datetime.date(1974, 4, 26)], dtype=object),
# ...
#  datetime.date(1975, 2, 4): array([datetime.date(1975, 2, 4)], dtype=object),
#  datetime.date(1975, 2, 5): array([datetime.date(1975, 2, 5)], dtype=object),
#  datetime.date(1975, 2, 6): array([datetime.date(1975, 2, 6)], dtype=object),
#  datetime.date(1975, 2, 7): array([datetime.date(1975, 2, 7)], dtype=object),
#  datetime.date(1975, 2, 10): array([datetime.date(1975, 2, 10)], dtype=object),
#  datetime.date(1975, 2, 11): array([datetime.date(1975, 2, 11)], dtype=object),
#  datetime.date(1975, 2, 12): array([datetime.date(1975, 2, 12)], dtype=object),
#  datetime.date(1975, 2, 13): array([datetime.date(1975, 2, 13)], dtype=object),
#  datetime.date(1975, 2, 14): array([datetime.date(1975, 2, 14)], dtype=object),
#  datetime.date(1975, 2, 17): array([datetime.date(1975, 2, 17)], dtype=object),
#  datetime.date(1975, 2, 18): array([datetime.date(1975, 2, 18)], dtype=object),
#  datetime.date(1975, 2, 19): array([datetime.date(1975, 2, 19)], dtype=object),
#  datetime.date(1975, 2, 20): array([datetime.date(1975, 2, 20)], dtype=object),
#  datetime.date(1975, 2, 21): array([datetime.date(1975, 2, 21)], dtype=object),
#  datetime.date(1975, 2, 24): array([datetime.date(1975, 2, 24)], dtype=object),
#  datetime.date(1975, 2, 25): array([datetime.date(1975, 2, 25)], dtype=object),
#  datetime.date(1975, 2, 26): array([datetime.date(1975, 2, 26)], dtype=object),
#  datetime.date(1975, 2, 27): array([datetime.date(1975, 2, 27)], dtype=object),
#  datetime.date(1975, 2, 28): array([datetime.date(1975, 2, 28)], dtype=object),
#  datetime.date(1975, 3, 3): array([datetime.date(1975, 3, 3)], dtype=object),
#  datetime.date(1975, 3, 4): array([datetime.date(1975, 3, 4)], dtype=object),
#  datetime.date(1975, 3, 5): array([datetime.date(1975, 3, 5)], dtype=object),
#  datetime.date(1975, 3, 6): array([datetime.date(1975, 3, 6)], dtype=object),
#  datetime.date(1975, 3, 7): array([datetime.date(1975, 3, 7)], dtype=object),
#  datetime.date(1975, 3, 10): array([datetime.date(1975, 3, 10)], dtype=object),
#  datetime.date(1975, 3, 11): array([datetime.date(1975, 3, 11)], dtype=object),
#  datetime.date(1975, 3, 12): array([datetime.date(1975, 3, 12)], dtype=object),
#  datetime.date(1975, 3, 13): array([datetime.date(1975, 3, 13)], dtype=object),
#  datetime.date(1975, 3, 14): array([datetime.date(1975, 3, 14)], dtype=object),
#  datetime.date(1975, 3, 17): array([datetime.date(1975, 3, 17)], dtype=object),
#  datetime.date(1975, 3, 18): array([datetime.date(1975, 3, 18)], dtype=object),
#  datetime.date(1975, 3, 19): array([datetime.date(1975, 3, 19)], dtype=object),
#  datetime.date(1975, 3, 20): array([datetime.date(1975, 3, 20)], dtype=object),
#  datetime.date(1975, 3, 21): array([datetime.date(1975, 3, 21)], dtype=object),
#  datetime.date(1975, 3, 24): array([datetime.date(1975, 3, 24)], dtype=object),
#  datetime.date(1975, 3, 25): array([datetime.date(1975, 3, 25)], dtype=object),
#  datetime.date(1975, 3, 26): array([datetime.date(1975, 3, 26)], dtype=object),
#  datetime.date(1975, 3, 27): array([datetime.date(1975, 3, 27)], dtype=object),
#  datetime.date(1975, 3, 28): array([datetime.date(1975, 3, 28)], dtype=object),
#  datetime.date(1975, 3, 31): array([datetime.date(1975, 3, 31)], dtype=object),
#  datetime.date(1975, 4, 1): array([datetime.date(1975, 4, 1)], dtype=object),
#  datetime.date(1975, 4, 2): array([datetime.date(1975, 4, 2)], dtype=object),
#  datetime.date(1975, 4, 3): array([datetime.date(1975, 4, 3)], dtype=object),
#  datetime.date(1975, 4, 4): array([datetime.date(1975, 4, 4)], dtype=object),
#  datetime.date(1975, 4, 7): array([datetime.date(1975, 4, 7)], dtype=object),
#  datetime.date(1975, 4, 8): array([datetime.date(1975, 4, 8)], dtype=object),
#  datetime.date(1975, 4, 9): array([datetime.date(1975, 4, 9)], dtype=object),
#  datetime.date(1975, 4, 10): array([datetime.date(1975, 4, 10)], dtype=object),
#  datetime.date(1975, 4, 11): array([datetime.date(1975, 4, 11)], dtype=object),
#  datetime.date(1975, 4, 14): array([datetime.date(1975, 4, 14)], dtype=object),
#  datetime.date(1975, 4, 15): array([datetime.date(1975, 4, 15)], dtype=object),
#  datetime.date(1975, 4, 16): array([datetime.date(1975, 4, 16)], dtype=object),
#  datetime.date(1975, 4, 17): array([datetime.date(1975, 4, 17)], dtype=object),
#  datetime.date(1975, 4, 18): array([datetime.date(1975, 4, 18)], dtype=object),
#  datetime.date(1975, 4, 21): array([datetime.date(1975, 4, 21)], dtype=object),
#  datetime.date(1975, 4, 22): array([datetime.date(1975, 4, 22)], dtype=object),
#  datetime.date(1975, 4, 23): array([datetime.date(1975, 4, 23)], dtype=object),
#  datetime.date(1975, 4, 24): array([datetime.date(1975, 4, 24)], dtype=object),
#  datetime.date(1975, 4, 25): array([datetime.date(1975, 4, 25)], dtype=object),
#  datetime.date(1975, 4, 28): array([datetime.date(1975, 4, 28)], dtype=object),
#  datetime.date(1975, 4, 29): array([datetime.date(1975, 4, 29)], dtype=object),
#  datetime.date(1975, 4, 30): array([datetime.date(1975, 4, 30)], dtype=object),
#  datetime.date(1975, 5, 1): array([datetime.date(1975, 5, 1)], dtype=object),
#  datetime.date(1975, 5, 2): array([datetime.date(1975, 5, 2)], dtype=object),
#  datetime.date(1975, 5, 5): array([datetime.date(1975, 5, 5)], dtype=object),
#  datetime.date(1975, 5, 6): array([datetime.date(1975, 5, 6)], dtype=object),
#  datetime.date(1975, 5, 7): array([datetime.date(1975, 5, 7)], dtype=object),
#  datetime.date(1975, 5, 8): array([datetime.date(1975, 5, 8)], dtype=object),
#  datetime.date(1975, 5, 9): array([datetime.date(1975, 5, 9)], dtype=object),
#  datetime.date(1975, 5, 12): array([datetime.date(1975, 5, 12)], dtype=object),
#  datetime.date(1975, 5, 13): array([datetime.date(1975, 5, 13)], dtype=object),
#  datetime.date(1975, 5, 14): array([datetime.date(1975, 5, 14)], dtype=object),
#  datetime.date(1975, 5, 15): array([datetime.date(1975, 5, 15)], dtype=object),
#  datetime.date(1975, 5, 16): array([datetime.date(1975, 5, 16)], dtype=object),
#  datetime.date(1975, 5, 19): array([datetime.date(1975, 5, 19)], dtype=object),
#  datetime.date(1975, 5, 20): array([datetime.date(1975, 5, 20)], dtype=object),
#  datetime.date(1975, 5, 21): array([datetime.date(1975, 5, 21)], dtype=object),
#  datetime.date(1975, 5, 22): array([datetime.date(1975, 5, 22)], dtype=object),
#  datetime.date(1975, 5, 23): array([datetime.date(1975, 5, 23)], dtype=object),
#  datetime.date(1975, 5, 26): array([datetime.date(1975, 5, 26)], dtype=object),
#  datetime.date(1975, 5, 27): array([datetime.date(1975, 5, 27)], dtype=object),
#  datetime.date(1975, 5, 28): array([datetime.date(1975, 5, 28)], dtype=object),
#  datetime.date(1975, 5, 29): array([datetime.date(1975, 5, 29)], dtype=object),
#  datetime.date(1975, 5, 30): array([datetime.date(1975, 5, 30)], dtype=object),
#  datetime.date(1975, 6, 2): array([datetime.date(1975, 6, 2)], dtype=object),
#  datetime.date(1975, 6, 3): array([datetime.date(1975, 6, 3)], dtype=object),
#  datetime.date(1975, 6, 4): array([datetime.date(1975, 6, 4)], dtype=object),
#  datetime.date(1975, 6, 5): array([datetime.date(1975, 6, 5)], dtype=object),
#  datetime.date(1975, 6, 6): array([datetime.date(1975, 6, 6)], dtype=object),
#  datetime.date(1975, 6, 9): array([datetime.date(1975, 6, 9)], dtype=object),
#  datetime.date(1975, 6, 10): array([datetime.date(1975, 6, 10)], dtype=object),
#  datetime.date(1975, 6, 11): array([datetime.date(1975, 6, 11)], dtype=object),
#  datetime.date(1975, 6, 12): array([datetime.date(1975, 6, 12)], dtype=object),
#  datetime.date(1975, 6, 13): array([datetime.date(1975, 6, 13)], dtype=object),
#  datetime.date(1975, 6, 16): array([datetime.date(1975, 6, 16)], dtype=object),
#  datetime.date(1975, 6, 17): array([datetime.date(1975, 6, 17)], dtype=object),
#  datetime.date(1975, 6, 18): array([datetime.date(1975, 6, 18)], dtype=object),
#  datetime.date(1975, 6, 19): array([datetime.date(1975, 6, 19)], dtype=object),
#  datetime.date(1975, 6, 20): array([datetime.date(1975, 6, 20)], dtype=object),
#  datetime.date(1975, 6, 23): array([datetime.date(1975, 6, 23)], dtype=object),
#  datetime.date(1975, 6, 24): array([datetime.date(1975, 6, 24)], dtype=object),
#  datetime.date(1975, 6, 25): array([datetime.date(1975, 6, 25)], dtype=object),
#  datetime.date(1975, 6, 26): array([datetime.date(1975, 6, 26)], dtype=object),
#  datetime.date(1975, 6, 27): array([datetime.date(1975, 6, 27)], dtype=object),
#  datetime.date(1975, 6, 30): array([datetime.date(1975, 6, 30)], dtype=object),
#  datetime.date(1975, 7, 1): array([datetime.date(1975, 7, 1)], dtype=object),
#  datetime.date(1975, 7, 2): array([datetime.date(1975, 7, 2)], dtype=object),
#  datetime.date(1975, 7, 3): array([datetime.date(1975, 7, 3)], dtype=object),
#  datetime.date(1975, 7, 4): array([datetime.date(1975, 7, 4)], dtype=object),
#  datetime.date(1975, 7, 7): array([datetime.date(1975, 7, 7)], dtype=object),
#  datetime.date(1975, 7, 8): array([datetime.date(1975, 7, 8)], dtype=object),
#  datetime.date(1975, 7, 9): array([datetime.date(1975, 7, 9)], dtype=object),
#  datetime.date(1975, 7, 10): array([datetime.date(1975, 7, 10)], dtype=object),
#  datetime.date(1975, 7, 11): array([datetime.date(1975, 7, 11)], dtype=object),
#  datetime.date(1975, 7, 14): array([datetime.date(1975, 7, 14)], dtype=object),
#  datetime.date(1975, 7, 15): array([datetime.date(1975, 7, 15)], dtype=object),
#  datetime.date(1975, 7, 16): array([datetime.date(1975, 7, 16)], dtype=object),
#  datetime.date(1975, 7, 17): array([datetime.date(1975, 7, 17)], dtype=object),
#  datetime.date(1975, 7, 18): array([datetime.date(1975, 7, 18)], dtype=object),
#  datetime.date(1975, 7, 21): array([datetime.date(1975, 7, 21)], dtype=object),
#  datetime.date(1975, 7, 22): array([datetime.date(1975, 7, 22)], dtype=object),
#  datetime.date(1975, 7, 23): array([datetime.date(1975, 7, 23)], dtype=object),
#  datetime.date(1975, 7, 24): array([datetime.date(1975, 7, 24)], dtype=object),
#  datetime.date(1975, 7, 25): array([datetime.date(1975, 7, 25)], dtype=object),
#  datetime.date(1975, 7, 28): array([datetime.date(1975, 7, 28)], dtype=object),
#  datetime.date(1975, 7, 29): array([datetime.date(1975, 7, 29)], dtype=object),
#  datetime.date(1975, 7, 30): array([datetime.date(1975, 7, 30)], dtype=object),
#  datetime.date(1975, 7, 31): array([datetime.date(1975, 7, 31)], dtype=object),
#  datetime.date(1975, 8, 1): array([datetime.date(1975, 8, 1)], dtype=object),
#  datetime.date(1975, 8, 4): array([datetime.date(1975, 8, 4)], dtype=object),
#  datetime.date(1975, 8, 5): array([datetime.date(1975, 8, 5)], dtype=object),
#  datetime.date(1975, 8, 6): array([datetime.date(1975, 8, 6)], dtype=object),
#  datetime.date(1975, 8, 7): array([datetime.date(1975, 8, 7)], dtype=object),
#  datetime.date(1975, 8, 8): array([datetime.date(1975, 8, 8)], dtype=object),
#  datetime.date(1975, 8, 11): array([datetime.date(1975, 8, 11)], dtype=object),
#  datetime.date(1975, 8, 12): array([datetime.date(1975, 8, 12)], dtype=object),
#  datetime.date(1975, 8, 13): array([datetime.date(1975, 8, 13)], dtype=object),
#  datetime.date(1975, 8, 14): array([datetime.date(1975, 8, 14)], dtype=object),
#  datetime.date(1975, 8, 15): array([datetime.date(1975, 8, 15)], dtype=object),
#  datetime.date(1975, 8, 18): array([datetime.date(1975, 8, 18)], dtype=object),
#  datetime.date(1975, 8, 19): array([datetime.date(1975, 8, 19)], dtype=object),
#  datetime.date(1975, 8, 20): array([datetime.date(1975, 8, 20)], dtype=object),
#  datetime.date(1975, 8, 21): array([datetime.date(1975, 8, 21)], dtype=object),
#  datetime.date(1975, 8, 22): array([datetime.date(1975, 8, 22)], dtype=object),
#  datetime.date(1975, 8, 25): array([datetime.date(1975, 8, 25)], dtype=object),
#  datetime.date(1975, 8, 26): array([datetime.date(1975, 8, 26)], dtype=object),
#  datetime.date(1975, 8, 27): array([datetime.date(1975, 8, 27)], dtype=object),
#  datetime.date(1975, 8, 28): array([datetime.date(1975, 8, 28)], dtype=object),
#  datetime.date(1975, 8, 29): array([datetime.date(1975, 8, 29)], dtype=object),
#  datetime.date(1975, 9, 1): array([datetime.date(1975, 9, 1)], dtype=object),
#  datetime.date(1975, 9, 2): array([datetime.date(1975, 9, 2)], dtype=object),
#  datetime.date(1975, 9, 3): array([datetime.date(1975, 9, 3)], dtype=object),
#  datetime.date(1975, 9, 4): array([datetime.date(1975, 9, 4)], dtype=object),
#  datetime.date(1975, 9, 5): array([datetime.date(1975, 9, 5)], dtype=object),
#  datetime.date(1975, 9, 8): array([datetime.date(1975, 9, 8)], dtype=object),
#  datetime.date(1975, 9, 9): array([datetime.date(1975, 9, 9)], dtype=object),
#  datetime.date(1975, 9, 10): array([datetime.date(1975, 9, 10)], dtype=object),
#  datetime.date(1975, 9, 11): array([datetime.date(1975, 9, 11)], dtype=object),
#  datetime.date(1975, 9, 12): array([datetime.date(1975, 9, 12)], dtype=object),
#  datetime.date(1975, 9, 15): array([datetime.date(1975, 9, 15)], dtype=object),
#  datetime.date(1975, 9, 16): array([datetime.date(1975, 9, 16)], dtype=object),
#  datetime.date(1975, 9, 17): array([datetime.date(1975, 9, 17)], dtype=object),
#  datetime.date(1975, 9, 18): array([datetime.date(1975, 9, 18)], dtype=object),
#  datetime.date(1975, 9, 19): array([datetime.date(1975, 9, 19)], dtype=object),
#  datetime.date(1975, 9, 22): array([datetime.date(1975, 9, 22)], dtype=object),
#  datetime.date(1975, 9, 23): array([datetime.date(1975, 9, 23)], dtype=object),
#  datetime.date(1975, 9, 24): array([datetime.date(1975, 9, 24)], dtype=object),
#  datetime.date(1975, 9, 25): array([datetime.date(1975, 9, 25)], dtype=object),
#  datetime.date(1975, 9, 26): array([datetime.date(1975, 9, 26)], dtype=object),
#  datetime.date(1975, 9, 29): array([datetime.date(1975, 9, 29)], dtype=object),
#  datetime.date(1975, 9, 30): array([datetime.date(1975, 9, 30)], dtype=object),
#  datetime.date(1975, 10, 1): array([datetime.date(1975, 10, 1)], dtype=object),
#  datetime.date(1975, 10, 2): array([datetime.date(1975, 10, 2)], dtype=object),
#  datetime.date(1975, 10, 3): array([datetime.date(1975, 10, 3)], dtype=object),
#  datetime.date(1975, 10, 6): array([datetime.date(1975, 10, 6)], dtype=object),
#  datetime.date(1975, 10, 7): array([datetime.date(1975, 10, 7)], dtype=object),
#  datetime.date(1975, 10, 8): array([datetime.date(1975, 10, 8)], dtype=object),
#  datetime.date(1975, 10, 9): array([datetime.date(1975, 10, 9)], dtype=object),
#  datetime.date(1975, 10, 10): array([datetime.date(1975, 10, 10)], dtype=object),
#  datetime.date(1975, 10, 13): array([datetime.date(1975, 10, 13)], dtype=object),
#  datetime.date(1975, 10, 14): array([datetime.date(1975, 10, 14)], dtype=object),
#  datetime.date(1975, 10, 15): array([datetime.date(1975, 10, 15)], dtype=object),
#  datetime.date(1975, 10, 16): array([datetime.date(1975, 10, 16)], dtype=object),
#  datetime.date(1975, 10, 17): array([datetime.date(1975, 10, 17)], dtype=object),
#  datetime.date(1975, 10, 20): array([datetime.date(1975, 10, 20)], dtype=object),
#  datetime.date(1975, 10, 21): array([datetime.date(1975, 10, 21)], dtype=object),
#  datetime.date(1975, 10, 22): array([datetime.date(1975, 10, 22)], dtype=object),
#  datetime.date(1975, 10, 23): array([datetime.date(1975, 10, 23)], dtype=object),
#  datetime.date(1975, 10, 24): array([datetime.date(1975, 10, 24)], dtype=object),
#  datetime.date(1975, 10, 27): array([datetime.date(1975, 10, 27)], dtype=object),
#  datetime.date(1975, 10, 28): array([datetime.date(1975, 10, 28)], dtype=object),
#  datetime.date(1975, 10, 29): array([datetime.date(1975, 10, 29)], dtype=object),
#  datetime.date(1975, 10, 30): array([datetime.date(1975, 10, 30)], dtype=object),
#  datetime.date(1975, 10, 31): array([datetime.date(1975, 10, 31)], dtype=object),
#  datetime.date(1975, 11, 3): array([datetime.date(1975, 11, 3)], dtype=object),
#  datetime.date(1975, 11, 4): array([datetime.date(1975, 11, 4)], dtype=object),
#  datetime.date(1975, 11, 5): array([datetime.date(1975, 11, 5)], dtype=object),
#  datetime.date(1975, 11, 6): array([datetime.date(1975, 11, 6)], dtype=object),
#  datetime.date(1975, 11, 7): array([datetime.date(1975, 11, 7)], dtype=object),
#  datetime.date(1975, 11, 10): array([datetime.date(1975, 11, 10)], dtype=object),
#  ...}
